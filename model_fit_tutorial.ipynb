# %% [markdown]
# # BAGLE: Model Fitting Tutorial
# ### This Jupyter Notebook tutorial introduces how to model fit different microlensing events with the BAGLE model fitting functions. To read full docs, go [here](https://bagle.readthedocs.io/en/latest/PSPL_Solver.html#model_fitter.PSPL_Solver). To learn how to use BAGLE's model function, look at [this tutorial](https://github.com/MovingUniverseLab/BAGLE_Microlensing/blob/main/BAGLE_TUTORIAL.ipynb).
# By default, BAGLE uses a MultiNest sampling algorithm (a nested-sampling alternative to MCMC) with observed data to generate samples from posterior distributions.

# %% [markdown]
# ## Import modules
#
# In the general BAGLE model tutorial, we only needed to import model.py. For the case of model fitting, we will need to import the model.py function along with the model_fitter.py.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <b>Note:</b> For the sake of this tutorial, we will be using fake data based on a real microlensing event. Using this fake data involves importing the fake_data.py file as well. For personal uses, you will not use fake_data.
# </div>

# %%
from bagle import model, model_fitter, fake_data

# %% [markdown]
# Importing the ability to see images and os (to create directories in your base directory to put the output files):

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <b>Note:</b> The below modules will not be necessary when using the fitter. This is only used for the tutorial. Additionally, the make directory are used to signify where the output data and plots will go for this tutorial. Normal usages of the fitter will not necessarily need that code.
# </div>

# %%
from astropy.table import Table
import numpy as np
import os
from PIL import Image
from IPython.display import display
''' 
instead of the usual way of using markdown for images, viewing the images is coded in so that if changes are made
to the code by the user, running the code for the images will reflect these changes.
'''
os.makedirs('fit_files', exist_ok=True)
os.makedirs('astrom_test_files', exist_ok=True)

# %% [markdown]
# ### Import / generate your data

# %% [markdown]
# In any case when modelling a microlensing event, the data you have and the type of event varies. In this tutorial, we will be focusing on an event using only Photometry data and an event with no parallax.

# %%
data, p_in = fake_data.fake_data1()

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <b>Note:</b> fake_data() generates 2 variables: the data used for the fit (data), and the truth values that the data should fit to (p_in). When using this model fitter for real microlensing events, you will not have p_in, and so it is not used in this tutorial.
# </div>

# %% [markdown]
# PSPL_Solver is highly sensitive to which data you import. At minimum, you need Photometry data in the form of arrays in a dictionary. The fake data generator produces a data dictionary with the following key:value pairs:
#
# | Key | Input or Input type | Description |
# | --- | --- | --- |
# | target | NoPar / Par (string) | Describes if the target has or does not have parallax. |
# | phot_data | sim (string) | Source directory for the data. 'sim' is used in the case of simulated data. |
# | phot_files | string | File name of data. |
# | t_phot1 | MJD (array) | Array of times for the first photometric data set |
# | mag1 | magnitudes (array) | Array of magnitudes for the first photometric data set. |
# | mag_err1 | array | Error on previous mag1 array. |
#
# In the case you are fitting an event with astrometry, your dictionary must also include:
# | Key | Input or Input type | Description |
# | --- | --- | --- |
# | ast_data | sim (string) | Source directory for the data. 'sim' is used in the case of simulated data. |
# | ast_files | string | File name of data. |
# | t_ast1 | MJD (array) | Array of times for the first astrometric data set |
# | xpos1 | arcsec (array) | arcsec along East-West increasing to the East |
# | ypos1 | arcsec (array) | arcsec along the North-South increasing to the North |
# | xpos_err1 | array | Error on xpos |
# | ypos_err1 | array | Error on ypos |

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <b>Note:</b> The primary chunk of this tutorial will be using only Photometry data, but your data can still include the astrometry dictionaries, they will just not be used when making the fit.
# </div>

# %% [markdown]
# # Using PSPL_Solver

# %% [markdown]
# First, decide the microlensing model class of the event. This is described as one of the PSPL, BSPL, or PSBL subclasses in BAGLE. An example is:
#
# ```Python
# model.PSPL_Phot_noPar_Param1
# ```
# This takes into account photometry data with no parallax for a PSPL event. More model classes in [documentation](https://bagle.readthedocs.io/en/latest/ModelClass.html).

# %% [markdown]
# Next, you need to declare your fitter with this model in mind and with the data you imported earlier in the following format:
# ```Python
# fitter = model_fitter.PSPL_Solver(data,
#                      model.type)
# ```

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <b>Note:</b> Regardless of what model case you use (PSPL, PSBL, BSPL, etc.), you will still use the PSPL_Solver command. 'PSPL' is used in a general sense when declaring the fitter, and you only need to denote the model type in the model.param argument within the PSPL.solver command.
# </div>

# %% [markdown]
# ### Required arguments:
#
# - data
#   - Dictionary of arrays with required keys
# - model class
#   - Which microlensing model you are trying fit.
#
# ### Optional arguments added in this tutorial:
# - n_live_points (default=300)
#   - Number of points sampled in the priors
# - outputfiles_basename (default= 'chains/1-')
#   - Name of files' output. This name can include a different directory the files are going in.
#
# More arguments in [documentation](https://bagle.readthedocs.io/en/latest/PSPL_Solver.html#model_fitter.PSPL_Solver).

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Tip: </b> Regardless of what model class you use, for the PSPL_solver to work properly you must set n_live_points > dimensionality. When lacking highly fine tuned priors, the suggested number used for n_live_points is 50x your dimensionality. However, usually doing 20x to 30x your dimensionality is common practice. For this tutorial, we will only be using 200 using a model class with dimensionality 7.
# </div>

# %%
fitter = model_fitter.PSPL_Solver(data,
                     model.PSPL_Phot_noPar_Param1,
                     n_live_points=200,
                     outputfiles_basename='fit_files/test_')
# Out:
# ***** WARNING: ASTROMETRY DATA WILL NOT BE FIT BY <class 'bagle.model.PSPL_Phot_noPar_Param1'> *****

# %% [markdown]
# Now that we have our object, we will have to set our priors:

# %% [markdown]
# ## Priors:
#
# In the context of nested sampling, setting priors narrows down the location of where your points within the fit will sample from. Having priors allows for a more accurate plot as it sharpens the efficiency of the points that are sampling. However, making them too small might cause the best parameter to be out of range if you are unsure of the ranges that your value could be in. Set your priors based on information that works best with the data you have about the event.
#
# A prior can be set for any output parameter the model would have. You can find a list of parameters by model in the doumentation for [PSPL](https://bagle.readthedocs.io/en/latest/PSPL.html), [PSBL](https://bagle.readthedocs.io/en/latest/PSBL_Param.html), and [BSPL](https://bagle.readthedocs.io/en/latest/BSPL.html).
#
# Priors should be set in the following way:
# ```Python
# fitter.priors['param'] = model_fitter.make_gen(beginning_prior, ending_prior)
# ```

# %%
fitter.priors['t0'] = model_fitter.make_gen(56990, 57010) #MJD
fitter.priors['b_sff1'] = model_fitter.make_gen(0.5, 1.1) #ratio; no units
fitter.priors['mag_src1'] = model_fitter.make_gen(18.9, 19.1) #magnitude

# %% [markdown]
# To get the residuals plot (and other relevant plots if you include parallax and/ or astrometry), you will need to run your fit. You run your fit with the command `solve()`

# %%
fitter.solve()
# Out:
# *************************************************
# *** Using Prior for prior function. ***
# *************************************************
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  200
#  dimensionality =    7
#  *****************************************************
#  Starting MultiNest
#  generating live points
#  live points generated, starting sampling
# Acceptance Rate:                        0.988142
# Replacements:                                250
# Total Samples:                               253
# Nested Sampling ln(Z):            -248567.965670
# Acceptance Rate:                        0.946372
# Replacements:                                300
# Total Samples:                               317
# Nested Sampling ln(Z):            -187782.613378
# Acceptance Rate:                        0.815851
# Replacements:                                350
# Total Samples:                               429
# Nested Sampling ln(Z):            -159663.995076
# Acceptance Rate:                        0.763359
# Replacements:                                400
# Total Samples:                               524
# Nested Sampling ln(Z):            -134648.896979
# Acceptance Rate:                        0.700935
# Replacements:                                450
# Total Samples:                               642
# Nested Sampling ln(Z):            -109507.066664
# Acceptance Rate:                        0.690608
# Replacements:                                500
# Total Samples:                               724
# Nested Sampling ln(Z):             -88159.189647
# Acceptance Rate:                        0.674847
# Replacements:                                550
# Total Samples:                               815
# Nested Sampling ln(Z):             -66928.536175
# Acceptance Rate:                        0.665927
# Replacements:                                600
# Total Samples:                               901
# Nested Sampling ln(Z):             -54548.698580
# Acceptance Rate:                        0.655242
# Replacements:                                650
# Total Samples:                               992
# Nested Sampling ln(Z):             -44068.865395
# Acceptance Rate:                        0.650558
# Replacements:                                700
# Total Samples:                              1076
# Nested Sampling ln(Z):             -34328.610848
# Acceptance Rate:                        0.635055
# Replacements:                                750
# Total Samples:                              1181
# Nested Sampling ln(Z):             -28150.192250
# Acceptance Rate:                        0.629921
# Replacements:                                800
# Total Samples:                              1270
# Nested Sampling ln(Z):             -22599.748721
# Acceptance Rate:                        0.625000
# Replacements:                                850
# Total Samples:                              1360
# Nested Sampling ln(Z):             -17482.633744
# Acceptance Rate:                        0.618982
# Replacements:                                900
# Total Samples:                              1454
# Nested Sampling ln(Z):             -13443.718779
# Acceptance Rate:                        0.615285
# Replacements:                                950
# Total Samples:                              1544
# Nested Sampling ln(Z):             -10011.992779
# Acceptance Rate:                        0.610874
# Replacements:                               1000
# Total Samples:                              1637
# Nested Sampling ln(Z):              -7555.440939
# Acceptance Rate:                        0.608477
# Replacements:                               1091
# Total Samples:                              1793
# Nested Sampling ln(Z):              -3051.412889
# Acceptance Rate:                        0.602733
# Replacements:                               1191
# Total Samples:                              1976
# Nested Sampling ln(Z):                 82.661964
#
# UPDATE: Current MaxLogLike =  5690.353073085559
#
# Acceptance Rate:                        0.596856
# Replacements:                               1291
# Total Samples:                              2163
# Nested Sampling ln(Z):               1792.527213
# Acceptance Rate:                        0.581522
# Replacements:                               1391
# Total Samples:                              2392
# Nested Sampling ln(Z):               3266.275852
# Acceptance Rate:                        0.564773
# Replacements:                               1491
# Total Samples:                              2640
# Nested Sampling ln(Z):               4214.349655
# Acceptance Rate:                        0.556294
# Replacements:                               1591
# Total Samples:                              2860
# Nested Sampling ln(Z):               4692.051835
# Acceptance Rate:                        0.545308
# Replacements:                               1691
# Total Samples:                              3101
# Nested Sampling ln(Z):               5115.365488
# Acceptance Rate:                        0.534308
# Replacements:                               1791
# Total Samples:                              3352
# Nested Sampling ln(Z):               5348.755036
# Acceptance Rate:                        0.521224
# Replacements:                               1891
# Total Samples:                              3628
# Nested Sampling ln(Z):               5511.636011
# Acceptance Rate:                        0.513277
# Replacements:                               1991
# Total Samples:                              3879
# Nested Sampling ln(Z):               5676.190739
# Acceptance Rate:                        0.509255
# Replacements:                               2091
# Total Samples:                              4106
# Nested Sampling ln(Z):               5789.244932
# Acceptance Rate:                        0.507059
# Replacements:                               2191
# Total Samples:                              4321
# Nested Sampling ln(Z):               5890.183427
#
# UPDATE: Current MaxLogLike =  6256.7779559728115
#
# Acceptance Rate:                        0.506858
# Replacements:                               2291
# Total Samples:                              4520
# Nested Sampling ln(Z):               5975.986996
# Acceptance Rate:                        0.504643
# Replacements:                               2391
# Total Samples:                              4738
# Nested Sampling ln(Z):               6048.366778
# Acceptance Rate:                        0.494933
# Replacements:                               2491
# Total Samples:                              5033
# Nested Sampling ln(Z):               6096.489042
# Acceptance Rate:                        0.487580
# Replacements:                               2591
# Total Samples:                              5314
# Nested Sampling ln(Z):               6137.383338
# Acceptance Rate:                        0.479765
# Replacements:                               2691
# Total Samples:                              5609
# Nested Sampling ln(Z):               6159.067783
# Acceptance Rate:                        0.473211
# Replacements:                               2791
# Total Samples:                              5898
# Nested Sampling ln(Z):               6177.844282
# Acceptance Rate:                        0.469090
# Replacements:                               2891
# Total Samples:                              6163
# Nested Sampling ln(Z):               6196.582759
# Acceptance Rate:                        0.465380
# Replacements:                               2991
# Total Samples:                              6427
# Nested Sampling ln(Z):               6209.091119
# Acceptance Rate:                        0.460724
# Replacements:                               3091
# Total Samples:                              6709
# Nested Sampling ln(Z):               6217.570138
# Acceptance Rate:                        0.457229
# Replacements:                               3191
# Total Samples:                              6979
# Nested Sampling ln(Z):               6224.654771
#
# UPDATE: Current MaxLogLike =  6270.071669605548
#
# Acceptance Rate:                        0.455313
# Replacements:                               3291
# Total Samples:                              7228
# Nested Sampling ln(Z):               6230.145599
# Acceptance Rate:                        0.452797
# Replacements:                               3391
# Total Samples:                              7489
# Nested Sampling ln(Z):               6234.842714
# Acceptance Rate:                        0.446762
# Replacements:                               3491
# Total Samples:                              7814
# Nested Sampling ln(Z):               6238.492160
# Acceptance Rate:                        0.440830
# Replacements:                               3591
# Total Samples:                              8146
# Nested Sampling ln(Z):               6241.417673
# Acceptance Rate:                        0.438830
# Replacements:                               3691
# Total Samples:                              8411
# Nested Sampling ln(Z):               6243.268396
# Acceptance Rate:                        0.435297
# Replacements:                               3791
# Total Samples:                              8709
# Nested Sampling ln(Z):               6245.041815
# Acceptance Rate:                        0.429375
# Replacements:                               3891
# Total Samples:                              9062
# Nested Sampling ln(Z):               6246.396065
# Acceptance Rate:                        0.422552
# Replacements:                               3991
# Total Samples:                              9445
# Nested Sampling ln(Z):               6247.322787
# Acceptance Rate:                        0.417747
# Replacements:                               4091
# Total Samples:                              9793
# Nested Sampling ln(Z):               6247.942023
# Acceptance Rate:                        0.412744
# Replacements:                               4191
# Total Samples:                             10154
# Nested Sampling ln(Z):               6248.433635
#
# UPDATE: Current MaxLogLike =  6271.224947746673
#
# Acceptance Rate:                        0.406576
# Replacements:                               4291
# Total Samples:                             10554
# Nested Sampling ln(Z):               6248.790993
# Acceptance Rate:                        0.402364
# Replacements:                               4391
# Total Samples:                             10913
# Nested Sampling ln(Z):               6249.085890
# Acceptance Rate:                        0.398739
# Replacements:                               4491
# Total Samples:                             11263
# Nested Sampling ln(Z):               6249.308547
# Acceptance Rate:                        0.393200
# Replacements:                               4591
# Total Samples:                             11676
# Nested Sampling ln(Z):               6249.465153
#
# UPDATE: Current MaxLogLike =  6271.259985178716
#
# Acceptance Rate:                        0.390818
# Replacements:                               4682
# Total Samples:                             11980
# Nested Sampling ln(Z):               6249.563653
#
# UPDATE: Current MaxLogLike =  6271.259985178716
#
#  ln(ev)=   6249.7974781116682      +/-  0.30998187206247835
#  Total Likelihood Evaluations:        11980
#  Sampling finished. Exiting MultiNest

# %% [markdown]
# # Analyzing the output

# %% [markdown]
# ### Best fit parameters

# %% [markdown]
# You can get the best fit parameters in the form of a dictionary using `get_best_fit()`

# %%
fitter.get_best_fit()
# Out:
# {'t0': np.float64(56999.87393063865),
#  'u0_amp': np.float64(0.1274432631124962),
#  'tE': np.float64(174.60465700019282),
#  'piE_E': np.float64(0.9306804603771925),
#  'piE_N': np.float64(-0.7816500660563269),
#  'b_sff1': np.float64(1.0092945316763946),
#  'mag_src1': np.float64(18.991920573165235)}

# %% [markdown]
# Using the solve function in the model fitter outputs a PNG with the best fit parameters. This allows for a more formalized look at your parameters. These values are the same as we saw above, but in a PNG format. This PNG file is `basename_parameters.png` and look like

# %%
display(Image.open('fit_files/test_parameters.png').crop((0, 0, 1000, 400)))
# Out:
# <PIL.Image.Image image mode=RGBA size=1000x400>

# %% [markdown]
# ## Residuals plot

# %% [markdown]
# A residuals plot shows the observed data points with the best fit model around the data points. A good residuals plot will be one that consistently goes through the observed data points.
#
# You can see this file with `basename_phot_and_residuals_1.png`

# %%
display(Image.open('fit_files/test_phot_and_residuals_1.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1000x1000>

# %% [markdown]
# <b>Top:</b> Shows data points, their errors, and the line of best fit for the observed data.
#
# <b>Bottom:</b> Looks at the generic residuals plot, and subtracts the observed data point by the model it generates. These values are then plotted, with the x-axis staying constant from the generic residuals plot and the y-axis denoting the 'observed minus model'. This plot should be centered around 0, and major deviation with that questions the viability of the model.

# %% [markdown]
# ## Corner and trace plots

# %% [markdown]
# To gain insight into how the parameters would fit and their possible relationship to one another, you will need to run a separate command to output the corner and trace plots. This is done through running `plot_dynesty_style()`. There are several optional arguments for this function, but the most notable is the `fit_vals` argument:
#
# - fit_vals = [string; default=none]
#   - mean
#   - maxl (maximum likelihood)
#     - Found by maximizing the likelihood function (probability density of observed data)
#   - map (maximum a posteriori)
#     - Mode of the posterior distribution. This is a regularization of the maximum likelihood as it incorporates the prior distribution into the output quantity.
#
# Adding this argument adds another line to your plots, which would signify as listed in the form of a red line. They would not affect the content of your corner and trace plots, only adding another line.

# %%
fitter.plot_dynesty_style(fit_vals='maxl')

# %% [markdown]
# The name of the trace and corner files are `basename_dy_trace.png` and `basename_dy_corner.png` respectively.

# %%
display(Image.open('fit_files/test_dy_trace.png'), Image.open('fit_files/test_dy_corner.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1200x2100>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1600x1600>

# %% [markdown]
# <b>Top:</b> Trace plot: The trace plot shows two columns of plots, these plots are:
#
# <i>Left:</i> Evolution of the sample particles as a function of ln(X). The color denotes the weighted importance. In other words, their relative posterior mass.
#
# <i>Right:</i> The marginalized posteriors of the plotted particles graph to the left with a errors of the provided range.
#
# <b>Bottom:</b> Corner plot: On the outside diagonal, these plots are the same 1D posterior distributions seen in the trace plot above. On the inside are the 2D posterior distributions showing the relationship with the two parameters that are aligned for that plot. The more circular or scattered the plot is, the less the two parameters are correlated to one another. The more diagonal and thin the plot is, the more the two parameters are correlated to one another.
#
# In addition to these plots, you can also add a red line (discussed above) which notes each parameters' mean, maximum likelihood, or maximum a posteriori. These are added to the corner and trace plot. You can also get these values from looking into an output summary.fits:

# %%
summary=Table.read('fit_files/test_summary.fits')
summary
# Out:
# <Table length=3>
#      Mean_t0           Mean_u0_amp      ...        logZ            maxlogL
#      float64             float64        ...      float64           float64
# ------------------ -------------------- ... ----------------- -----------------
# 56999.902625532195 0.025904863673100263 ... 6249.563652503327 6271.259985178716
#  56999.90480034985  0.12609440191042165 ... 6249.292013703457 6271.259985178716
#  56999.89931837724   -0.126415537090366 ... 6248.873091275746 6271.224947746673

# %% [markdown]
# # Accuracy

# %% [markdown]
# One thing that is important is a numerical understanding in how accurate this fit is. To get the chi2 value, you can run the function `calc_chi2()`. You will need to divide this value by the degrees of freedom of the fit, which is just the sum of the data points in your array(s) + the number of parameters the fit can output.

# %% [markdown]
# <div class="alert alert-block alert-info">
#     If you are unaware of the number of parameters your fit will output, you can check with <b> len(model_class.fitter_param_names)</b> Additionally, if you are using astrometry data, make sure to add the length of the t_ast1 array to your "data point" summation to have an accurate degree of freedom and chi2 value.
# </div>

# %%
number_of_params = len(model.PSPL_Phot_noPar_Param1.fitter_param_names)
data_points = int(len(data['t_phot1']))  # + int(len(data['t_ast1'])) for PhotAstrom models
dof = data_points - number_of_params

# Work around BAGLE versions where calc_chi2('best') does not resolve correctly.
best_params = fitter.get_best_fit()
chi2_raw = fitter.calc_chi2(params=best_params, verbose=False)
chi2 = chi2_raw / dof

print('Raw chi2 value : ', chi2_raw, '\nActual chi2 value : ', chi2)
# Out:
# Raw chi2 value :  3976.434589096243
# Actual chi2 value :  0.9758121691033725

# %% [markdown]
# You can also see the raw chi2 values for the best fit parameters through the function `print_likelihood`

# %%
fitter.print_likelihood()
# Out:
# t0            = 56999.873931
# u0_amp        = 0.127443
# tE            = 174.604657
# piE_E         = 0.930680
# piE_N         = -0.781650
# b_sff1        = 1.009295
# mag_src1      = 18.991921
# lnL_phot      = 6271.259985
# lnL_ast       = 0.000000
# lnL           = 6271.259985
# chi2_phot1    = 3976.434589
# chi2_phot     = 3976.434589
# chi2_ast      = -0.000000
# chi2          = 3976.434589
# logL :           6271.3
# chi2 :           3976.4

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <b>Note:</b> The StDev values you can find in the <b>summary.fits</b> file are another way to analyze the accuracy of the fit by parameter as these values describe the errors on the posterior.
# </div>

# %% [markdown]
# # Final notes

# %% [markdown]
# To conclude this tutorial, it is important to note the different information and parameters the model fitter will output given just photometry data or photometry and astrometry data (at least in the case with no parallax).

# %% [markdown]
# ## *Photometry and Photometry-Astrometry output parameters comparisson*
#
# | Parameter | Phot | PhotAstrom | Description | Units |
# | --- | --- | --- | --- | --- |
# | mL |  | X | Lens mass| m_sun
# |t0| X | X | Time of photometric peak| MJD|
# |beta|  | X | Angular distance between lens and source| mas|
# |dL|  | X | Observer distance to lens|pc|
# |dL_dS|  | X | Ratio of observer distance from lens vs source | n/a|
# |XSO_E|  | X | Source at t0 in East direction|arcsec|
# |XSO_N|  | X |Dec of source at t0 |arcsec|
# |muL_E|  | X |RA lens proper motion |mas/yr|
# |mUL_N |  | X |Dec lens proper motion |mas/yr|
# |muS_E|  | X |RA source proper motion |mas/yr|
# |muS_N |  | X |Dec source proper motion |mas/yr|
# |b_sff1 | X | X | Ratio of source flux vs total |n/a|
# |mag_src1| X | X | Source photometric magnitude|n/a|
# |dS |  | X | Obsevrer disnace to source |pc|
# |tE | X | X | Einstein crossing time|days|
# |u0_amp| X | X |Distance apart between lens and source at t0|thetaE|
# |thetaE_E|  | X |Einstein radius in relative proper motion in East direction|mas|
# |thetaE_N|  | X |Einstein radius in relative proper motion in North direction|mas|
# |piE_E| X | X |Microlensing parallax in East direction|thetaE|
# |piE_N| X | X |Microlensing parallax in North Direction|thetaE|
# |muRel_E|  | X |RA source-lens relative proper motion |mas/yr|
# |muRel_N|  | X |Dec source-lens relative proper motion |mas/yr|

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Take away:</b> When you only using photometry, you will have less output parameters than if you include astrometry data. Dimensionality = number of parameters output.
# </div>

# %% [markdown]
# ### Here is an example of using Astrometry with the same fake input data

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     <b>Warning:</b> Processing this fit with astrometry data takes around 2 minutes, so do not close out of the kernel while it runs or the fit will fail.
# </div>

# %%
fitter_ast = model_fitter.PSPL_Solver(data,
                     model.PSPL_PhotAstrom_noPar_Param1,
                     n_live_points=200,
                     outputfiles_basename='astrom_test_files/photastrom_test_')

fitter_ast.priors['mL'] = model_fitter.make_gen(5.0, 15.0) #m_sun
fitter_ast.priors['t0'] = model_fitter.make_gen(56990, 57010) #MJD
fitter_ast.priors['beta'] = model_fitter.make_gen(-0.5, -0.3) #mas
fitter_ast.priors['muL_E'] = model_fitter.make_gen(-1, 1) #mas/yr
fitter_ast.priors['muL_N'] = model_fitter.make_gen(-8, -6) #mas/yr
fitter_ast.priors['muS_E'] = model_fitter.make_gen(0, 3) #mas/yr
fitter_ast.priors['muS_N'] = model_fitter.make_gen(-2, 1) #mas/yr
fitter_ast.priors['dL'] = model_fitter.make_gen(3000, 5000) #pc
fitter_ast.priors['dL_dS'] = model_fitter.make_gen(0.45, 0.55) #ratio; no units
fitter_ast.priors['b_sff1'] = model_fitter.make_gen(0.5, 1.1) #ratio; no units
fitter_ast.priors['mag_src1'] = model_fitter.make_gen(18.9, 19.1) #magnitude
fitter_ast.priors['xS0_E'] = model_fitter.make_gen(-10 ** -3, 10 ** -3) #arcsec
fitter_ast.priors['xS0_N'] = model_fitter.make_gen(-10 ** -3, 10 ** -3) #arcsec

fitter_ast.solve()
fitter_ast.plot_dynesty_style(fit_vals='maxl')
# Out:
# *************************************************
# *** Using Prior for prior function. ***
# *************************************************
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  200
#  dimensionality =   13
#  *****************************************************
#  Starting MultiNest
#  generating live points
#  live points generated, starting sampling
# Acceptance Rate:                        0.961538
# Replacements:                                250
# Total Samples:                               260
# Nested Sampling ln(Z):            -663981.493255
# Acceptance Rate:                        0.920245
# Replacements:                                300
# Total Samples:                               326
# Nested Sampling ln(Z):            -401050.189918
# Acceptance Rate:                        0.825472
# Replacements:                                350
# Total Samples:                               424
# Nested Sampling ln(Z):            -267403.561613
# Acceptance Rate:                        0.823045
# Replacements:                                400
# Total Samples:                               486
# Nested Sampling ln(Z):            -190708.888637
# Acceptance Rate:                        0.815217
# Replacements:                                450
# Total Samples:                               552
# Nested Sampling ln(Z):            -142882.842650
# Acceptance Rate:                        0.803859
# Replacements:                                500
# Total Samples:                               622
# Nested Sampling ln(Z):            -102679.902953
# Acceptance Rate:                        0.785714
# Replacements:                                550
# Total Samples:                               700
# Nested Sampling ln(Z):             -79182.620476
# Acceptance Rate:                        0.770218
# Replacements:                                600
# Total Samples:                               779
# Nested Sampling ln(Z):             -57970.548283
# Acceptance Rate:                        0.746269
# Replacements:                                650
# Total Samples:                               871
# Nested Sampling ln(Z):             -44192.274837
# Acceptance Rate:                        0.713558
# Replacements:                                700
# Total Samples:                               981
# Nested Sampling ln(Z):             -32814.709238
# Acceptance Rate:                        0.702247
# Replacements:                                750
# Total Samples:                              1068
# Nested Sampling ln(Z):             -26247.700742
# Acceptance Rate:                        0.692641
# Replacements:                                800
# Total Samples:                              1155
# Nested Sampling ln(Z):             -21018.638699
# Acceptance Rate:                        0.673534
# Replacements:                                850
# Total Samples:                              1262
# Nested Sampling ln(Z):             -16822.309643
# Acceptance Rate:                        0.662252
# Replacements:                                900
# Total Samples:                              1359
# Nested Sampling ln(Z):             -12820.842479
# Acceptance Rate:                        0.641892
# Replacements:                                950
# Total Samples:                              1480
# Nested Sampling ln(Z):             -10169.449329
# Acceptance Rate:                        0.639795
# Replacements:                               1000
# Total Samples:                              1563
# Nested Sampling ln(Z):              -7383.351168
# Acceptance Rate:                        0.635978
# Replacements:                               1050
# Total Samples:                              1651
# Nested Sampling ln(Z):              -5591.948865
# Acceptance Rate:                        0.622877
# Replacements:                               1100
# Total Samples:                              1766
# Nested Sampling ln(Z):              -4006.263062
# Acceptance Rate:                        0.612028
# Replacements:                               1150
# Total Samples:                              1879
# Nested Sampling ln(Z):              -2522.919458
#
# UPDATE: Current MaxLogLike =  7127.193914208683
#
# Acceptance Rate:                        0.600300
# Replacements:                               1200
# Total Samples:                              1999
# Nested Sampling ln(Z):              -1098.156951
# Acceptance Rate:                        0.580316
# Replacements:                               1250
# Total Samples:                              2154
# Nested Sampling ln(Z):                -83.300698
# Acceptance Rate:                        0.564481
# Replacements:                               1300
# Total Samples:                              2303
# Nested Sampling ln(Z):                754.710793
# Acceptance Rate:                        0.553733
# Replacements:                               1350
# Total Samples:                              2438
# Nested Sampling ln(Z):               1365.309459
# Acceptance Rate:                        0.541167
# Replacements:                               1400
# Total Samples:                              2587
# Nested Sampling ln(Z):               2020.910210
# Acceptance Rate:                        0.529197
# Replacements:                               1450
# Total Samples:                              2740
# Nested Sampling ln(Z):               2504.627149
# Acceptance Rate:                        0.521921
# Replacements:                               1500
# Total Samples:                              2874
# Nested Sampling ln(Z):               3069.412519
# Acceptance Rate:                        0.512736
# Replacements:                               1550
# Total Samples:                              3023
# Nested Sampling ln(Z):               3546.985154
# Acceptance Rate:                        0.495509
# Replacements:                               1600
# Total Samples:                              3229
# Nested Sampling ln(Z):               3914.145930
# Acceptance Rate:                        0.486582
# Replacements:                               1650
# Total Samples:                              3391
# Nested Sampling ln(Z):               4277.820643
# Acceptance Rate:                        0.481723
# Replacements:                               1700
# Total Samples:                              3529
# Nested Sampling ln(Z):               4592.851063
# Acceptance Rate:                        0.469169
# Replacements:                               1750
# Total Samples:                              3730
# Nested Sampling ln(Z):               4910.528075
# Acceptance Rate:                        0.459301
# Replacements:                               1800
# Total Samples:                              3919
# Nested Sampling ln(Z):               5246.743098
# Acceptance Rate:                        0.450122
# Replacements:                               1850
# Total Samples:                              4110
# Nested Sampling ln(Z):               5472.973512
# Acceptance Rate:                        0.442581
# Replacements:                               1900
# Total Samples:                              4293
# Nested Sampling ln(Z):               5687.730818
# Acceptance Rate:                        0.430844
# Replacements:                               1950
# Total Samples:                              4526
# Nested Sampling ln(Z):               5937.368925
# Acceptance Rate:                        0.423549
# Replacements:                               2000
# Total Samples:                              4722
# Nested Sampling ln(Z):               6090.351219
# Acceptance Rate:                        0.414812
# Replacements:                               2050
# Total Samples:                              4942
# Nested Sampling ln(Z):               6268.282965
# Acceptance Rate:                        0.405876
# Replacements:                               2100
# Total Samples:                              5174
# Nested Sampling ln(Z):               6420.369320
# Acceptance Rate:                        0.400671
# Replacements:                               2150
# Total Samples:                              5366
# Nested Sampling ln(Z):               6580.391695
#
# UPDATE: Current MaxLogLike =  8254.665321414941
#
# Acceptance Rate:                        0.393983
# Replacements:                               2200
# Total Samples:                              5584
# Nested Sampling ln(Z):               6747.842425
# Acceptance Rate:                        0.383632
# Replacements:                               2250
# Total Samples:                              5865
# Nested Sampling ln(Z):               6873.598986
# Acceptance Rate:                        0.373680
# Replacements:                               2300
# Total Samples:                              6155
# Nested Sampling ln(Z):               6953.705069
# Acceptance Rate:                        0.363159
# Replacements:                               2350
# Total Samples:                              6471
# Nested Sampling ln(Z):               7066.741789
# Acceptance Rate:                        0.354610
# Replacements:                               2400
# Total Samples:                              6768
# Nested Sampling ln(Z):               7152.027700
# Acceptance Rate:                        0.343619
# Replacements:                               2450
# Total Samples:                              7130
# Nested Sampling ln(Z):               7252.098711
# Acceptance Rate:                        0.337200
# Replacements:                               2500
# Total Samples:                              7414
# Nested Sampling ln(Z):               7337.085305
# Acceptance Rate:                        0.331083
# Replacements:                               2550
# Total Samples:                              7702
# Nested Sampling ln(Z):               7405.910899
# Acceptance Rate:                        0.324675
# Replacements:                               2600
# Total Samples:                              8008
# Nested Sampling ln(Z):               7488.766616
# Acceptance Rate:                        0.316758
# Replacements:                               2650
# Total Samples:                              8366
# Nested Sampling ln(Z):               7558.165066
# Acceptance Rate:                        0.307167
# Replacements:                               2700
# Total Samples:                              8790
# Nested Sampling ln(Z):               7625.834365
# Acceptance Rate:                        0.300087
# Replacements:                               2750
# Total Samples:                              9164
# Nested Sampling ln(Z):               7685.265318
# Acceptance Rate:                        0.295079
# Replacements:                               2800
# Total Samples:                              9489
# Nested Sampling ln(Z):               7741.031210
# Acceptance Rate:                        0.289958
# Replacements:                               2850
# Total Samples:                              9829
# Nested Sampling ln(Z):               7796.524337
# Acceptance Rate:                        0.285911
# Replacements:                               2900
# Total Samples:                             10143
# Nested Sampling ln(Z):               7853.878569
# Acceptance Rate:                        0.281327
# Replacements:                               2950
# Total Samples:                             10486
# Nested Sampling ln(Z):               7896.096158
# Acceptance Rate:                        0.275811
# Replacements:                               3000
# Total Samples:                             10877
# Nested Sampling ln(Z):               7942.174826
# Acceptance Rate:                        0.269363
# Replacements:                               3050
# Total Samples:                             11323
# Nested Sampling ln(Z):               7981.452122
# Acceptance Rate:                        0.265684
# Replacements:                               3100
# Total Samples:                             11668
# Nested Sampling ln(Z):               8012.451558
# Acceptance Rate:                        0.260567
# Replacements:                               3150
# Total Samples:                             12089
# Nested Sampling ln(Z):               8052.911756
#
# UPDATE: Current MaxLogLike =  8447.555543429455
#
# Acceptance Rate:                        0.254311
# Replacements:                               3200
# Total Samples:                             12583
# Nested Sampling ln(Z):               8087.489016
# Acceptance Rate:                        0.247525
# Replacements:                               3250
# Total Samples:                             13130
# Nested Sampling ln(Z):               8121.472822
# Acceptance Rate:                        0.242969
# Replacements:                               3300
# Total Samples:                             13582
# Nested Sampling ln(Z):               8141.906528
# Acceptance Rate:                        0.237859
# Replacements:                               3350
# Total Samples:                             14084
# Nested Sampling ln(Z):               8163.457611
# Acceptance Rate:                        0.233533
# Replacements:                               3400
# Total Samples:                             14559
# Nested Sampling ln(Z):               8191.920217
# Acceptance Rate:                        0.227153
# Replacements:                               3450
# Total Samples:                             15188
# Nested Sampling ln(Z):               8212.813788
# Acceptance Rate:                        0.220848
# Replacements:                               3500
# Total Samples:                             15848
# Nested Sampling ln(Z):               8230.626870
# Acceptance Rate:                        0.216252
# Replacements:                               3550
# Total Samples:                             16416
# Nested Sampling ln(Z):               8247.612815
# Acceptance Rate:                        0.210182
# Replacements:                               3600
# Total Samples:                             17128
# Nested Sampling ln(Z):               8264.926178
# Acceptance Rate:                        0.206028
# Replacements:                               3650
# Total Samples:                             17716
# Nested Sampling ln(Z):               8281.679586
# Acceptance Rate:                        0.201382
# Replacements:                               3700
# Total Samples:                             18373
# Nested Sampling ln(Z):               8297.287522
# Acceptance Rate:                        0.198876
# Replacements:                               3750
# Total Samples:                             18856
# Nested Sampling ln(Z):               8310.044494
# Acceptance Rate:                        0.195192
# Replacements:                               3800
# Total Samples:                             19468
# Nested Sampling ln(Z):               8324.134351
# Acceptance Rate:                        0.191162
# Replacements:                               3850
# Total Samples:                             20140
# Nested Sampling ln(Z):               8333.966575
# Acceptance Rate:                        0.188024
# Replacements:                               3900
# Total Samples:                             20742
# Nested Sampling ln(Z):               8345.733162
# Acceptance Rate:                        0.182811
# Replacements:                               3950
# Total Samples:                             21607
# Nested Sampling ln(Z):               8358.084291
# Acceptance Rate:                        0.180963
# Replacements:                               4000
# Total Samples:                             22104
# Nested Sampling ln(Z):               8367.787309
# Acceptance Rate:                        0.177999
# Replacements:                               4050
# Total Samples:                             22753
# Nested Sampling ln(Z):               8378.202126
# Acceptance Rate:                        0.174431
# Replacements:                               4100
# Total Samples:                             23505
# Nested Sampling ln(Z):               8387.351251
# Acceptance Rate:                        0.169824
# Replacements:                               4150
# Total Samples:                             24437
# Nested Sampling ln(Z):               8394.620185
#
# UPDATE: Current MaxLogLike =  8519.941729280039
#
# Acceptance Rate:                        0.166726
# Replacements:                               4200
# Total Samples:                             25191
# Nested Sampling ln(Z):               8402.491160
# Acceptance Rate:                        0.163657
# Replacements:                               4250
# Total Samples:                             25969
# Nested Sampling ln(Z):               8409.325951
# Acceptance Rate:                        0.161527
# Replacements:                               4300
# Total Samples:                             26621
# Nested Sampling ln(Z):               8417.371647
# Acceptance Rate:                        0.157495
# Replacements:                               4350
# Total Samples:                             27620
# Nested Sampling ln(Z):               8424.739808
# Acceptance Rate:                        0.153868
# Replacements:                               4400
# Total Samples:                             28596
# Nested Sampling ln(Z):               8429.528398
# Acceptance Rate:                        0.150059
# Replacements:                               4450
# Total Samples:                             29655
# Nested Sampling ln(Z):               8434.418584
# Acceptance Rate:                        0.145891
# Replacements:                               4500
# Total Samples:                             30845
# Nested Sampling ln(Z):               8439.075151
# Acceptance Rate:                        0.143905
# Replacements:                               4550
# Total Samples:                             31618
# Nested Sampling ln(Z):               8443.217055
# Acceptance Rate:                        0.141621
# Replacements:                               4600
# Total Samples:                             32481
# Nested Sampling ln(Z):               8447.376533
# Acceptance Rate:                        0.138212
# Replacements:                               4650
# Total Samples:                             33644
# Nested Sampling ln(Z):               8452.689306
# Acceptance Rate:                        0.134509
# Replacements:                               4700
# Total Samples:                             34942
# Nested Sampling ln(Z):               8456.673685
# Acceptance Rate:                        0.129845
# Replacements:                               4750
# Total Samples:                             36582
# Nested Sampling ln(Z):               8459.830962
# Acceptance Rate:                        0.127314
# Replacements:                               4800
# Total Samples:                             37702
# Nested Sampling ln(Z):               8463.311740
# Acceptance Rate:                        0.123838
# Replacements:                               4850
# Total Samples:                             39164
# Nested Sampling ln(Z):               8466.059402
# Acceptance Rate:                        0.120467
# Replacements:                               4900
# Total Samples:                             40675
# Nested Sampling ln(Z):               8468.752242
# Acceptance Rate:                        0.116925
# Replacements:                               4950
# Total Samples:                             42335
# Nested Sampling ln(Z):               8471.946821
# Acceptance Rate:                        0.113817
# Replacements:                               5000
# Total Samples:                             43930
# Nested Sampling ln(Z):               8475.416602
# Acceptance Rate:                        0.110547
# Replacements:                               5050
# Total Samples:                             45682
# Nested Sampling ln(Z):               8478.434561
# Acceptance Rate:                        0.108051
# Replacements:                               5100
# Total Samples:                             47200
# Nested Sampling ln(Z):               8480.741531
# Acceptance Rate:                        0.105485
# Replacements:                               5150
# Total Samples:                             48822
# Nested Sampling ln(Z):               8482.761396
#
# UPDATE: Current MaxLogLike =  8536.353787361186
#
# Acceptance Rate:                        0.103207
# Replacements:                               5200
# Total Samples:                             50384
# Nested Sampling ln(Z):               8484.378815
# Acceptance Rate:                        0.100996
# Replacements:                               5250
# Total Samples:                             51982
# Nested Sampling ln(Z):               8486.080183
# Acceptance Rate:                        0.098235
# Replacements:                               5300
# Total Samples:                             53952
# Nested Sampling ln(Z):               8487.515182
# Acceptance Rate:                        0.095784
# Replacements:                               5350
# Total Samples:                             55855
# Nested Sampling ln(Z):               8488.945389
# Acceptance Rate:                        0.093179
# Replacements:                               5400
# Total Samples:                             57953
# Nested Sampling ln(Z):               8490.770651
# Acceptance Rate:                        0.090452
# Replacements:                               5450
# Total Samples:                             60253
# Nested Sampling ln(Z):               8492.452313
# Acceptance Rate:                        0.087962
# Replacements:                               5500
# Total Samples:                             62527
# Nested Sampling ln(Z):               8493.889626
# Acceptance Rate:                        0.085777
# Replacements:                               5550
# Total Samples:                             64703
# Nested Sampling ln(Z):               8495.116802
# Acceptance Rate:                        0.083677
# Replacements:                               5600
# Total Samples:                             66924
# Nested Sampling ln(Z):               8496.238644
# Acceptance Rate:                        0.080740
# Replacements:                               5650
# Total Samples:                             69978
# Nested Sampling ln(Z):               8497.249002
# Acceptance Rate:                        0.078523
# Replacements:                               5700
# Total Samples:                             72590
# Nested Sampling ln(Z):               8498.255351
# Acceptance Rate:                        0.076425
# Replacements:                               5750
# Total Samples:                             75237
# Nested Sampling ln(Z):               8499.190639
# Acceptance Rate:                        0.074545
# Replacements:                               5800
# Total Samples:                             77805
# Nested Sampling ln(Z):               8500.124611
# Acceptance Rate:                        0.072777
# Replacements:                               5850
# Total Samples:                             80382
# Nested Sampling ln(Z):               8500.950017
# Acceptance Rate:                        0.071083
# Replacements:                               5900
# Total Samples:                             83001
# Nested Sampling ln(Z):               8501.643384
# Acceptance Rate:                        0.069477
# Replacements:                               5950
# Total Samples:                             85640
# Nested Sampling ln(Z):               8502.294724
# Acceptance Rate:                        0.067890
# Replacements:                               6000
# Total Samples:                             88378
# Nested Sampling ln(Z):               8502.986099
# Acceptance Rate:                        0.066261
# Replacements:                               6050
# Total Samples:                             91306
# Nested Sampling ln(Z):               8503.678515
# Acceptance Rate:                        0.065283
# Replacements:                               6100
# Total Samples:                             93439
# Nested Sampling ln(Z):               8504.309962
# Acceptance Rate:                        0.063610
# Replacements:                               6150
# Total Samples:                             96683
# Nested Sampling ln(Z):               8504.829538
#
# UPDATE: Current MaxLogLike =  8545.260621542633
#
# Acceptance Rate:                        0.062309
# Replacements:                               6200
# Total Samples:                             99504
# Nested Sampling ln(Z):               8505.306643
# Acceptance Rate:                        0.060887
# Replacements:                               6250
# Total Samples:                            102650
# Nested Sampling ln(Z):               8505.749722
# Acceptance Rate:                        0.059380
# Replacements:                               6300
# Total Samples:                            106096
# Nested Sampling ln(Z):               8506.199972
# Acceptance Rate:                        0.058423
# Replacements:                               6350
# Total Samples:                            108691
# Nested Sampling ln(Z):               8506.647445
# Acceptance Rate:                        0.057175
# Replacements:                               6400
# Total Samples:                            111937
# Nested Sampling ln(Z):               8507.082512
# Acceptance Rate:                        0.056481
# Replacements:                               6450
# Total Samples:                            114197
# Nested Sampling ln(Z):               8507.462014
# Acceptance Rate:                        0.055019
# Replacements:                               6500
# Total Samples:                            118141
# Nested Sampling ln(Z):               8507.794382
# Acceptance Rate:                        0.053869
# Replacements:                               6550
# Total Samples:                            121592
# Nested Sampling ln(Z):               8508.096006
# Acceptance Rate:                        0.052359
# Replacements:                               6600
# Total Samples:                            126054
# Nested Sampling ln(Z):               8508.386177
# Acceptance Rate:                        0.051465
# Replacements:                               6650
# Total Samples:                            129214
# Nested Sampling ln(Z):               8508.656125
# Acceptance Rate:                        0.050434
# Replacements:                               6700
# Total Samples:                            132847
# Nested Sampling ln(Z):               8508.905019
# Acceptance Rate:                        0.048920
# Replacements:                               6750
# Total Samples:                            137981
# Nested Sampling ln(Z):               8509.128947
# Acceptance Rate:                        0.047684
# Replacements:                               6800
# Total Samples:                            142604
# Nested Sampling ln(Z):               8509.337050
# Acceptance Rate:                        0.046904
# Replacements:                               6850
# Total Samples:                            146044
# Nested Sampling ln(Z):               8509.522199
# Acceptance Rate:                        0.045954
# Replacements:                               6900
# Total Samples:                            150151
# Nested Sampling ln(Z):               8509.697160
# Acceptance Rate:                        0.044790
# Replacements:                               6950
# Total Samples:                            155170
# Nested Sampling ln(Z):               8509.850785
# Acceptance Rate:                        0.043796
# Replacements:                               7000
# Total Samples:                            159833
# Nested Sampling ln(Z):               8509.979908
# Acceptance Rate:                        0.042965
# Replacements:                               7050
# Total Samples:                            164088
# Nested Sampling ln(Z):               8510.095924
# Acceptance Rate:                        0.042022
# Replacements:                               7100
# Total Samples:                            168959
# Nested Sampling ln(Z):               8510.201850
# Acceptance Rate:                        0.041235
# Replacements:                               7150
# Total Samples:                            173396
# Nested Sampling ln(Z):               8510.299323
#
# UPDATE: Current MaxLogLike =  8547.675446920917
#
# Acceptance Rate:                        0.040604
# Replacements:                               7200
# Total Samples:                            177322
# Nested Sampling ln(Z):               8510.388928
# Acceptance Rate:                        0.039708
# Replacements:                               7250
# Total Samples:                            182585
# Nested Sampling ln(Z):               8510.471649
# Acceptance Rate:                        0.039171
# Replacements:                               7300
# Total Samples:                            186360
# Nested Sampling ln(Z):               8510.545863
# Acceptance Rate:                        0.038574
# Replacements:                               7350
# Total Samples:                            190542
# Nested Sampling ln(Z):               8510.611666
# Acceptance Rate:                        0.037700
# Replacements:                               7400
# Total Samples:                            196285
# Nested Sampling ln(Z):               8510.669016
# Acceptance Rate:                        0.037083
# Replacements:                               7450
# Total Samples:                            200903
# Nested Sampling ln(Z):               8510.719876
# Acceptance Rate:                        0.036590
# Replacements:                               7500
# Total Samples:                            204973
# Nested Sampling ln(Z):               8510.764567
# Acceptance Rate:                        0.036083
# Replacements:                               7550
# Total Samples:                            209241
# Nested Sampling ln(Z):               8510.803753
# Acceptance Rate:                        0.035639
# Replacements:                               7600
# Total Samples:                            213248
# Nested Sampling ln(Z):               8510.838118
# Acceptance Rate:                        0.035143
# Replacements:                               7650
# Total Samples:                            217681
# Nested Sampling ln(Z):               8510.868121
# Acceptance Rate:                        0.034667
# Replacements:                               7700
# Total Samples:                            222113
# Nested Sampling ln(Z):               8510.893816
# Acceptance Rate:                        0.034264
# Replacements:                               7750
# Total Samples:                            226186
# Nested Sampling ln(Z):               8510.916123
#
# UPDATE: Current MaxLogLike =  8548.026938310199
#
# Acceptance Rate:                        0.034253
# Replacements:                               7761
# Total Samples:                            226580
# Nested Sampling ln(Z):               8510.920608
#
# UPDATE: Current MaxLogLike =  8548.026938310199
#
#  ln(ev)=   8511.0581479190914      +/-  0.40551885915981328
#  Total Likelihood Evaluations:       226580
#  Sampling finished. Exiting MultiNest

# %% [markdown]
# Including astrometry data allows for more parameters to output, but also more plots. Some example of these plots are the `[basename]_astr_remove_pm_1.png`

# %%
display(Image.open('astrom_test_files/photastrom_test_astr_remove_pm_1.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>

# %% [markdown]
# This plot looks at astrometric shift without proper motion (hence 'remove_pm' in the image title) of the micorlensing event by change in dec (y-axis) and RA (x-axis). In understanding that the model we used is with no parallax, something that looks like a loop is to be expected. The color bar denotes the time of observation for the data in MJD.
#
# Another new type of plot you'll see when adding astrometry data in your fitting run is `[basename]_astr_on_sky_1.png`

# %%
display(Image.open('astrom_test_files/photastrom_test_astr_on_sky_1.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1000x1000>

# %% [markdown]
# This plot is the astrometry plot without subtracting proper motion by dec (y-axis) and RA (x-axis). The wobble in the middle of the plot shows that the event analyzed is a microlensing event between two (or more) objects. A comparison, for example, is that when looking at a single star, this line will be generally straight across without the wobble in the middle. Keep in mind this is without parallax.

# %% [markdown]
# # Running alternatives
# Running fits in a Jupyter notebook is highly advised against as Jupyter runs slowly and eats up RAM quickly. A work around is to put all your fit code into a .py file and run it with the code `python path/example_file.py`. Even with running it through python though, most fits will take hours to even weeks to run depending on the data, priors, or model. A way to make this work faster is to run your .py file faster is through multithreading. The code you will use to multithread is: `mpirun -np -4 python path/example_file.py` where the 4 represents the number of threads you are using. It does not exactly have to be 4, this was just used as an example.
