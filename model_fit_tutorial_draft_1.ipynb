# %% [markdown]
# # BAGLE: Model Fitting Tutorial

# %% [markdown]
# ### This Jupyter Notebook tutorial introduces how to model fit different microlensing events with the BAGLE model fitting functions. To read full docs, go [here](https://bagle.readthedocs.io/en/latest/PSPL_Solver.html#model_fitter.PSPL_Solver)

# %% [markdown]
# By default, BAGLE uses a MultiNest sampling algorithm (a nested-sampling alternative to MCMC) with observed data to generate samples from prosterier disctributions.

# %% [markdown]
# ## Import modules
#
# In the general BAGLE model tutorial, we only needed to import model.py. For the case of model fitting, we will need to import the model.py function along with the model_fitter.py.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <b>Note:</b> For the sake of this tutorial, we will be using fake data based on a real microlensing event. Using this fake data involves importing the fake_data.py file as well. For personal uses, you will not use fake_data.
# </div>

# %%
from bagle import model, model_fitter, fake_data
from astropy.table import Table
import numpy as np

# %% [markdown]
# Importing the ability to see images and os (to create directories in your base directory to put the output files):

# %%
import os
from PIL import Image
from IPython.display import display

default = os.getcwd()
os.makedirs('fit_files', exist_ok=True)
os.makedirs('astrom_test_files', exist_ok=True)

# %% [markdown]
# ### Import your data

# %% [markdown]
# In any case when modelling a microlensing event, the data you have and the type of event varies. In this tutorial, we will be focusing on an event using only Photometery data and an event with no parallax.

# %%
data, p_in = fake_data.fake_data1()

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <b>Note:</b> p_in is being imported because fake_data imports 2 values: the data used for the fit, and the actual values the fit should output when comparing it to the original microlensing event the fake data is based off of. When using this model fitter for personal usage, you will not have p_in, and it is not used in this tutorial.
# </div>

# %% [markdown]
# PSPL_Solver is highly sensitive to which data you import. At minimum, you need Photometery data in the form of arrays in a dictionary. Make sure the data dictionary you import has the following keys:
# - target ('NoPar' vs 'Par')
# - phot_data ('sim')
# - phot_files ('filename')
# - t_phot1 (MJD; array)
# - mag1 (magnitudes; array)
# - mag_err1 (magnitude error; array)
# - raL (decimal degrees; array)
# - decL (decimal degrees; array)
#
# In the case you are fitting an event with astrometery, your dictionary must also include:
# - ast_data(sim)
# - ast_files ('filename')
# - t_ast1 (MJD; array)
# - xpos1 (arcsec along East-West increasing to the East; array)
# - ypos1 (arcsec along the North-South increasing to the North; array)
# - xpos_err1 (arcsec; array)
# - ypos_err1 (arcsec; array)

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <b>Note:</b> The primary chunk of this tutroial will be using only Photometry data, but your data can still include the astrometery dictionaries, they will just not be used when making the fit.
# </div>

# %% [markdown]
# ## Using PSPL_Solver

# %% [markdown]
# First, decide the microlensing model class you are hoping to fit and declare its parameters. This is described as one of the PSPL subclasses in BAGLE. An example is:
#
# ```Python
# model.PSPL_Phot_noPar_Param1
# ```
# This takes into account photometry data with no parallax. More model classes in [documentation](https://bagle.readthedocs.io/en/latest/ModelClass.html).

# %% [markdown]
# Next, you need to declare your fitter with this model in mind and with the data you imported earlier in the following format:
# ```Python
# fitter = model_fitter.PSPL_Solver(data,
#                      model.param)
# ```

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <b>Note:</b> Regardless of what model case you use (PSPL, PSBL, BSPL, etc.), you will still use the PSPL_Solver command. 'PSPL' is used in a general sense when declaring the fitter, and you only need to denote the model type in the model.param arugment within the PSPL.solver command.
# </div>

# %% [markdown]
# ### Required arguments:
#
# - data
#   - Dictionary of arrays with required keys
# - model class
#   - Which microlensing model you are trying fit. Explanation as above.
#
# ### Optional arguements added in this tutorial:
# - n_live_points (default=300)
#   - Number of points sampled in the priors
# - outputfiles_basename (default= 'chains/1-')
#   - Name of files' output. This name can include a different directory the files are going in.
#
# More arguements in documentation.

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Tip: </b> Regardless of what model class you use, for the PSPL_solver to work properly you must set n_live_points > dimensionality. When lacking highly fine tuned priors, the suggested number used for n_live_points is 50x your dimensionality. However, usually doing 20x to 30x your dimensionality is common practice. For this tutorial, we will only be using 200 using a model class with dimensionalty 7.
# </div>

# %%
fitter = model_fitter.PSPL_Solver(data,
                     model.PSPL_Phot_noPar_Param1,
                     n_live_points=200,
                     outputfiles_basename='fit_files/test_')
# Out:
# ***** WARNING: ASTROMETRY DATA WILL NOT BE FIT BY <class 'bagle.model.PSPL_Phot_noPar_Param1'> *****

# %% [markdown]
# ## Priors:
#
# In the context of nested sampling, setting priors narrows down the location of where your points within the fit will sample from. Having priors allows for a more accurate plot as it sharpens the effiency of the points that are sampling. However, making them too small might cause the best paramater to be out of range if you are unsure of the ranges that your value could be in. Set your priors based on information that works best with the data you have about the event.
#
# Priors should be set in the following way:
# ```Python
# fitter.priors['param'] = model_fitter.make_gen(beginning_prior, ending_prior)
# ```

# %%
fitter.priors['mL'] = model_fitter.make_gen(5.0, 15.0)
fitter.priors['t0'] = model_fitter.make_gen(56990, 57010)
fitter.priors['beta'] = model_fitter.make_gen(-0.5, -0.3)
fitter.priors['muL_E'] = model_fitter.make_gen(-1, 1)
fitter.priors['muL_N'] = model_fitter.make_gen(-8, -6)
fitter.priors['muS_E'] = model_fitter.make_gen(0, 3)
fitter.priors['muS_N'] = model_fitter.make_gen(-2, 1)
fitter.priors['dL'] = model_fitter.make_gen(3000, 5000)
fitter.priors['dL_dS'] = model_fitter.make_gen(0.45, 0.55)
fitter.priors['b_sff1'] = model_fitter.make_gen(0.5, 1.1)
fitter.priors['mag_src1'] = model_fitter.make_gen(18.9, 19.1)
fitter.priors['xS0_E'] = model_fitter.make_gen(-10 ** -3, 10 ** -3)
fitter.priors['xS0_N'] = model_fitter.make_gen(-10 ** -3, 10 ** -3)

# %% [markdown]
# To get the residuals plot (and other relevant plots if you include parallax and/ or astrometry), you will need to run your fit. You run your fit with the command `solve()`

# %%
fitter.solve()
# Out:
# *************************************************
# *** Using Prior for prior function. ***
# *************************************************
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  200
#  dimensionality =    7
#  *****************************************************
#  Starting MultiNest
#  generating live points
#  live points generated, starting sampling
# Acceptance Rate:                        0.965251
# Replacements:                                250
# Total Samples:                               259
# Nested Sampling ln(Z):            -223599.635268
# Acceptance Rate:                        0.906344
# Replacements:                                300
# Total Samples:                               331
# Nested Sampling ln(Z):            -187335.654904
# Acceptance Rate:                        0.829384
# Replacements:                                350
# Total Samples:                               422
# Nested Sampling ln(Z):            -155750.770624
# Acceptance Rate:                        0.743494
# Replacements:                                400
# Total Samples:                               538
# Nested Sampling ln(Z):            -132142.662394
# Acceptance Rate:                        0.704225
# Replacements:                                450
# Total Samples:                               639
# Nested Sampling ln(Z):            -112235.443517
# Acceptance Rate:                        0.683995
# Replacements:                                500
# Total Samples:                               731
# Nested Sampling ln(Z):             -88995.543153
# Acceptance Rate:                        0.666667
# Replacements:                                550
# Total Samples:                               825
# Nested Sampling ln(Z):             -72115.068823
# Acceptance Rate:                        0.652884
# Replacements:                                600
# Total Samples:                               919
# Nested Sampling ln(Z):             -58111.871753
# Acceptance Rate:                        0.634146
# Replacements:                                650
# Total Samples:                              1025
# Nested Sampling ln(Z):             -41936.547594
# Acceptance Rate:                        0.617829
# Replacements:                                700
# Total Samples:                              1133
# Nested Sampling ln(Z):             -33628.815389
# Acceptance Rate:                        0.606306
# Replacements:                                750
# Total Samples:                              1237
# Nested Sampling ln(Z):             -25034.248529
# Acceptance Rate:                        0.594796
# Replacements:                                800
# Total Samples:                              1345
# Nested Sampling ln(Z):             -20734.557707
# Acceptance Rate:                        0.593161
# Replacements:                                850
# Total Samples:                              1433
# Nested Sampling ln(Z):             -16425.666955
# Acceptance Rate:                        0.583658
# Replacements:                                900
# Total Samples:                              1542
# Nested Sampling ln(Z):             -12465.769641
# Acceptance Rate:                        0.587145
# Replacements:                                950
# Total Samples:                              1618
# Nested Sampling ln(Z):              -9108.760024
# Acceptance Rate:                        0.582411
# Replacements:                               1000
# Total Samples:                              1717
# Nested Sampling ln(Z):              -6556.862112
# Acceptance Rate:                        0.577554
# Replacements:                               1091
# Total Samples:                              1889
# Nested Sampling ln(Z):              -2290.987198
# Acceptance Rate:                        0.572321
# Replacements:                               1191
# Total Samples:                              2081
# Nested Sampling ln(Z):                196.777178
#
# UPDATE: Current MaxLogLike =  5863.626321340824
#
# Acceptance Rate:                        0.560330
# Replacements:                               1291
# Total Samples:                              2304
# Nested Sampling ln(Z):               2461.442156
# Acceptance Rate:                        0.538313
# Replacements:                               1391
# Total Samples:                              2584
# Nested Sampling ln(Z):               3623.629171
# Acceptance Rate:                        0.528162
# Replacements:                               1491
# Total Samples:                              2823
# Nested Sampling ln(Z):               4370.631599
# Acceptance Rate:                        0.524736
# Replacements:                               1591
# Total Samples:                              3032
# Nested Sampling ln(Z):               4881.677083
# Acceptance Rate:                        0.522882
# Replacements:                               1691
# Total Samples:                              3234
# Nested Sampling ln(Z):               5250.097123
# Acceptance Rate:                        0.517331
# Replacements:                               1791
# Total Samples:                              3462
# Nested Sampling ln(Z):               5493.839690
# Acceptance Rate:                        0.512189
# Replacements:                               1891
# Total Samples:                              3692
# Nested Sampling ln(Z):               5716.947181
# Acceptance Rate:                        0.507132
# Replacements:                               1991
# Total Samples:                              3926
# Nested Sampling ln(Z):               5900.541943
# Acceptance Rate:                        0.497265
# Replacements:                               2091
# Total Samples:                              4205
# Nested Sampling ln(Z):               5989.382479
# Acceptance Rate:                        0.490157
# Replacements:                               2191
# Total Samples:                              4470
# Nested Sampling ln(Z):               6065.725483
#
# UPDATE: Current MaxLogLike =  6271.57914743403
#
# Acceptance Rate:                        0.486205
# Replacements:                               2291
# Total Samples:                              4712
# Nested Sampling ln(Z):               6115.975532
# Acceptance Rate:                        0.478104
# Replacements:                               2391
# Total Samples:                              5001
# Nested Sampling ln(Z):               6156.651448
# Acceptance Rate:                        0.473935
# Replacements:                               2491
# Total Samples:                              5256
# Nested Sampling ln(Z):               6179.476938
# Acceptance Rate:                        0.471605
# Replacements:                               2591
# Total Samples:                              5494
# Nested Sampling ln(Z):               6201.838731
# Acceptance Rate:                        0.466216
# Replacements:                               2691
# Total Samples:                              5772
# Nested Sampling ln(Z):               6219.952751
# Acceptance Rate:                        0.460409
# Replacements:                               2791
# Total Samples:                              6062
# Nested Sampling ln(Z):               6230.900319
# Acceptance Rate:                        0.454989
# Replacements:                               2891
# Total Samples:                              6354
# Nested Sampling ln(Z):               6242.248377
# Acceptance Rate:                        0.450045
# Replacements:                               2991
# Total Samples:                              6646
# Nested Sampling ln(Z):               6249.200661
# Acceptance Rate:                        0.443091
# Replacements:                               3091
# Total Samples:                              6976
# Nested Sampling ln(Z):               6253.062904
# Acceptance Rate:                        0.433442
# Replacements:                               3191
# Total Samples:                              7362
# Nested Sampling ln(Z):               6255.591109
#
# UPDATE: Current MaxLogLike =  6283.84012962507
#
# Acceptance Rate:                        0.426461
# Replacements:                               3291
# Total Samples:                              7717
# Nested Sampling ln(Z):               6257.553998
# Acceptance Rate:                        0.420407
# Replacements:                               3391
# Total Samples:                              8066
# Nested Sampling ln(Z):               6259.042158
# Acceptance Rate:                        0.415200
# Replacements:                               3491
# Total Samples:                              8408
# Nested Sampling ln(Z):               6260.418014
# Acceptance Rate:                        0.408439
# Replacements:                               3591
# Total Samples:                              8792
# Nested Sampling ln(Z):               6261.365787
# Acceptance Rate:                        0.401283
# Replacements:                               3691
# Total Samples:                              9198
# Nested Sampling ln(Z):               6261.959649
# Acceptance Rate:                        0.393829
# Replacements:                               3791
# Total Samples:                              9626
# Nested Sampling ln(Z):               6262.383100
# Acceptance Rate:                        0.387511
# Replacements:                               3891
# Total Samples:                             10041
# Nested Sampling ln(Z):               6262.678491
# Acceptance Rate:                        0.379589
# Replacements:                               3991
# Total Samples:                             10514
# Nested Sampling ln(Z):               6262.884190
# Acceptance Rate:                        0.371748
# Replacements:                               4087
# Total Samples:                             10994
# Nested Sampling ln(Z):               6263.022751
# Acceptance Rate:                        0.367309
# Replacements:                               4137
# Total Samples:                             11263
# Nested Sampling ln(Z):               6263.044384
# Acceptance Rate:                        0.364087
# Replacements:                               4187
# Total Samples:                             11500
# Nested Sampling ln(Z):               6263.086399
#
# UPDATE: Current MaxLogLike =  6285.050288714356
#
# Acceptance Rate:                        0.361827
# Replacements:                               4237
# Total Samples:                             11710
# Nested Sampling ln(Z):               6263.153343
# Acceptance Rate:                        0.359467
# Replacements:                               4287
# Total Samples:                             11926
# Nested Sampling ln(Z):               6263.253403
# Acceptance Rate:                        0.357514
# Replacements:                               4337
# Total Samples:                             12131
# Nested Sampling ln(Z):               6263.368715
# Acceptance Rate:                        0.351889
# Replacements:                               4387
# Total Samples:                             12467
# Nested Sampling ln(Z):               6263.477037
# Acceptance Rate:                        0.350446
# Replacements:                               4437
# Total Samples:                             12661
# Nested Sampling ln(Z):               6263.569110
# Acceptance Rate:                        0.348532
# Replacements:                               4487
# Total Samples:                             12874
# Nested Sampling ln(Z):               6263.644989
# Acceptance Rate:                        0.346230
# Replacements:                               4537
# Total Samples:                             13104
# Nested Sampling ln(Z):               6263.704888
# Acceptance Rate:                        0.344369
# Replacements:                               4587
# Total Samples:                             13320
# Nested Sampling ln(Z):               6263.752137
#
# UPDATE: Current MaxLogLike =  6285.083097069071
#
# Acceptance Rate:                        0.343890
# Replacements:                               4604
# Total Samples:                             13388
# Nested Sampling ln(Z):               6263.765890
#
# UPDATE: Current MaxLogLike =  6285.083097069071
#
#  ln(ev)=   6263.9926834683647      +/-  0.30679730666813121
#  Total Likelihood Evaluations:        13388
#  Sampling finished. Exiting MultiNest

# %% [markdown]
# # Analyzing the output

# %% [markdown]
# ### Best fit parameters

# %% [markdown]
# You can get the best fit parameters in the form of a dictionary using `get_best_fit()`

# %%
fitter.get_best_fit()
# Out:
# {'t0': 56999.97075031211,
#  'u0_amp': 0.12408368950395454,
#  'tE': 175.0727577389876,
#  'piE_E': -0.7662819529911293,
#  'piE_N': 0.9270797147849512,
#  'b_sff1': 0.9981845083612956,
#  'mag_src1': 19.004796031006343}

# %% [markdown]
# Using the solve function in the model fitter outputs a PNG with the best fit parameters. This allows for a more formalized look at your parameters. These values are the same as we saw above, but in a PNG format. This PNG file is `basename_paramaters.png` and look like

# %%
display(Image.open('fit_files/test_parameters.png').crop((0, 0, 1000, 400)))
# Out:
# <PIL.Image.Image image mode=RGBA size=1000x400>

# %% [markdown]
# ## Residuals plot

# %% [markdown]
# A residuals plot shows the observed data points with the best fit model around the data points. A good residuals plot will be one that consistently goes through the observed data points.
#
# You can see this file with `basename_phot_and_residuals_1.png`

# %%
display(Image.open('fit_files/test_phot_and_residuals_1.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1000x1000>

# %% [markdown]
# <b>Top:</b> Shows data points, their errors, and the line of best fit for the oberved data.
#
# <b>Bottom:</b> Standarized residuals plot: Looks at the generic residuals plot, and subtraces the observed data point by the model it generates. These values are then plotted, with the x-axis staying constant from the generic residuals plot and the y-axis denoting the observed minus model. This plot should be centered around 0, and major deviation with that questions the viability of the model.

# %% [markdown]
# ## Corner and trace plots

# %% [markdown]
# To gain insight into how the parameters would fit and their possible relationship to one another, you will need to run a seperate command to output the corner and trace plots. This is done through running `plot_dynesty_style()`. There are several optional arguements for this function, but the most notable is the `fit_vals` arguement:
#
# - fit_vals = [string; default=none]
#   - mean
#   - maxl (maximum likelihood)
#     - Found by maximizing the likelihood function (probability density of observed data)
#   - map (maximum a posteriori)
#     - Mode of the posterier distribution. This is a regularization of the maximum likelihood as it incorportates the prior distribution into the output quantity.
#
# Adding this arguement adds another line to your plots, which would signify as listed in the form of a red line. They would not affect the content of your corner and trace plots, only adding another line.

# %%
fitter.plot_dynesty_style(fit_vals='mean')

# %% [markdown]
# The name of the trace and corner files are `basename_dy_trace.png` and `basename_dy_corner.png` respectively.

# %%
display(Image.open('fit_files/test_dy_trace.png'), Image.open('fit_files/test_dy_corner.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1200x2100>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1600x1600>

# %% [markdown]
# <b>Top:</b> Trace plot
#
# <i>Left:</i> Evolution of the sample particles as a function of ln(X). The color denotes the weighted importance. In other words, their relative posterior mass.
#
# <i>Right:</i> The marginalized posteriors of the plotted particles graph to the left with a standard deviation  2% of the provided range.
#
# <b>Bottom:</b> Corner plot: On the outside diagonal, these plots are the same 1D posterior distributions seen in the trace plot above. On the inside are the 2D posterior distrubutions showing the relationship with the two parameters that are aligned for that plot. The more circular or scattered the plot is, the less the two parameters are correlated to one another. The more diagonal and thin the plot is, the more the two parameters are corrleated to one another.
#
# In addiition to these plots, you can also add a red line (discussed above) which notes each paramters' mean, maximum likelihood, or maximum a posteriori. These are added to the corner and trace plot. You can also get these values from looking into an output summary.fits:

# %%
summary=Table.read('fit_files/test_summary.fits')
summary
# Out:
# <Table length=3>
#      Mean_t0            Mean_u0_amp      ...        logZ           maxlogL
#      float64              float64        ...      float64          float64
# ------------------ --------------------- ... ----------------- ----------------
# 56999.884110411236 -0.005705589011445107 ... 6263.532807077967 6284.98018258868
#   56999.8746106471   -0.1262377978372833 ... 6263.128672958182  6284.9241358646
# 56999.894464972676    0.1256838592152059 ... 6263.042424168418 6284.98018258868

# %% [markdown]
# # Accuracy

# %% [markdown]
# One thing that is important is a numerical understanding in how accurate this fit is. To get the chi2 value, you can run the function `calc_chi2()`. You will need to divide this value by the degrees of freedom of the fit, which is just the sum of the data points in your array(s) + the number of parameters the fit can output.

# %% [markdown]
# <div class="alert alert-block alert-info">
#     If you are unaware of the number of parameters your fit will output, you can check with <b> len(model_class.fitter_param_names)</b> Additionally, if you are using astrometery data, make sure to add the length of the t_ast1 array to your "data point" summation to have an accuarate degree of freedom and chi2 value.
# </div>

# %%
number_of_params=len(model.PSPL_Phot_noPar_Param1.fitter_param_names)
data_points=int(len(data['t_phot1'])) # + int(len(data['t_ast1']))
dof= number_of_params+data_points

chi2_raw=fitter.calc_chi2(params='best', verbose=False)
chi2=chi2_raw/dof

print('Raw chi2 value : ', chi2_raw, '\nActual chi2 value : ', chi2)
# Out:
# Raw chi2 value :  3948.994194276316
# Actual chi2 value :  0.9667060451104813

# %% [markdown]
# You can also see the raw chi2 values for the best fit paramaters through the function `print_likelihood`

# %%
fitter.print_likelihood()
# Out:
# t0            = 56999.970750
# u0_amp        = 0.124084
# tE            = 175.072758
# piE_E         = -0.766282
# piE_N         = 0.927080
# b_sff1        = 0.998185
# mag_src1      = 19.004796
# lnL_phot      = 6284.980183
# lnL_ast       = 0.000000
# lnL           = 6284.980183
# chi2_phot1    = 3948.994194
# chi2_phot     = 3948.994194
# chi2_ast      = -0.000000
# chi2          = 3948.994194
# logL :           6285.0
# chi2 :           3949.0

# %% [markdown]
# # Final notes

# %% [markdown]
# To conclude this tutorial, it is important to note the different information and parameters the model fitter will output given just photometery data or photometery and astrometery data (atleast in the case with no parallax).

# %% [markdown]
# ## *Phot_noPar vs PhotAstrom_noPar*
#
# ### PhotAstrom Output Params
# - mL
# - t0
# - beta
# - dL
# - dL_dS
# - XSO E
# - XSO N
# - muL E
# - mUL N
# - muS_E
# - muS N
# - b_sff1
# - mag_src1
# - dS
# - tE
# - u0 amp
# - thetaE E
# - thetaE N
# - piE E
# - piE N
# - muRel E
# - muRel N
#
# ### PhotAstrom PNGs
# - All in documentation
#
# ### Phot Output Params
# - t0
# - u0_amp
# - tE
# - pIE E
# - piE N
# - b sff1
# - mag_src1
#
# ### Phot PNGs
# - [basename]parameters.png
# - [basename]phot_and_residuals_1.png
#
# ### Take away
# When you only using photometry, you will have less output parameters than if you include astrometery data. Dimensioality = number of paramaters output.

# %% [markdown]
# ### Here is an expample of using Astrometery with the same fake input data

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     <b>Warning:</b> Processing this fit with astrometery data takes around 2 minutes, so do not close out of the kernel while it runs or the fit will fail.
# </div>

# %%
fitter_ast = model_fitter.PSPL_Solver(data,
                     model.PSPL_PhotAstrom_noPar_Param1,
                     n_live_points=200,
                     outputfiles_basename='astrom_test_files/photastrom_test_')

fitter_ast.priors['mL'] = model_fitter.make_gen(5.0, 15.0)
fitter_ast.priors['t0'] = model_fitter.make_gen(56990, 57010)
fitter_ast.priors['beta'] = model_fitter.make_gen(-0.5, -0.3)
fitter_ast.priors['muL_E'] = model_fitter.make_gen(-1, 1)
fitter_ast.priors['muL_N'] = model_fitter.make_gen(-8, -6)
fitter_ast.priors['muS_E'] = model_fitter.make_gen(0, 3)
fitter_ast.priors['muS_N'] = model_fitter.make_gen(-2, 1)
fitter_ast.priors['dL'] = model_fitter.make_gen(3000, 5000)
fitter_ast.priors['dL_dS'] = model_fitter.make_gen(0.45, 0.55)
fitter_ast.priors['b_sff1'] = model_fitter.make_gen(0.5, 1.1)
fitter_ast.priors['mag_src1'] = model_fitter.make_gen(18.9, 19.1)
fitter_ast.priors['xS0_E'] = model_fitter.make_gen(-10 ** -3, 10 ** -3)
fitter_ast.priors['xS0_N'] = model_fitter.make_gen(-10 ** -3, 10 ** -3)

fitter_ast.solve()
fitter_ast.plot_dynesty_style(fit_vals='maxl')
# Out:
# *************************************************
# *** Using Prior for prior function. ***
# *************************************************
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  100
#  dimensionality =   13
#  *****************************************************
#  Starting MultiNest
#  generating live points
#  live points generated, starting sampling
# Acceptance Rate:                        0.892857
# Replacements:                                150
# Total Samples:                               168
# Nested Sampling ln(Z):            -206205.872656
# Acceptance Rate:                        0.800000
# Replacements:                                200
# Total Samples:                               250
# Nested Sampling ln(Z):            -131291.450190
# Acceptance Rate:                        0.759878
# Replacements:                                250
# Total Samples:                               329
# Nested Sampling ln(Z):             -83595.348722
# Acceptance Rate:                        0.715990
# Replacements:                                300
# Total Samples:                               419
# Nested Sampling ln(Z):             -54684.041806
# Acceptance Rate:                        0.687623
# Replacements:                                350
# Total Samples:                               509
# Nested Sampling ln(Z):             -31468.128686
# Acceptance Rate:                        0.671141
# Replacements:                                400
# Total Samples:                               596
# Nested Sampling ln(Z):             -20033.277398
# Acceptance Rate:                        0.614754
# Replacements:                                450
# Total Samples:                               732
# Nested Sampling ln(Z):             -12073.868227
# Acceptance Rate:                        0.606796
# Replacements:                                500
# Total Samples:                               824
# Nested Sampling ln(Z):              -6988.638104
# Acceptance Rate:                        0.592034
# Replacements:                                550
# Total Samples:                               929
# Nested Sampling ln(Z):              -3193.088008
# Acceptance Rate:                        0.581395
# Replacements:                                600
# Total Samples:                              1032
# Nested Sampling ln(Z):               -933.530862
# Acceptance Rate:                        0.564726
# Replacements:                                650
# Total Samples:                              1151
# Nested Sampling ln(Z):                964.850334
# Acceptance Rate:                        0.544747
# Replacements:                                700
# Total Samples:                              1285
# Nested Sampling ln(Z):               2549.511812
# Acceptance Rate:                        0.527426
# Replacements:                                750
# Total Samples:                              1422
# Nested Sampling ln(Z):               3432.482595
# Acceptance Rate:                        0.506009
# Replacements:                                800
# Total Samples:                              1581
# Nested Sampling ln(Z):               4017.548614
# Acceptance Rate:                        0.482406
# Replacements:                                850
# Total Samples:                              1762
# Nested Sampling ln(Z):               4533.714202
# Acceptance Rate:                        0.459888
# Replacements:                                900
# Total Samples:                              1957
# Nested Sampling ln(Z):               5100.109632
# Acceptance Rate:                        0.449173
# Replacements:                                950
# Total Samples:                              2115
# Nested Sampling ln(Z):               5544.083488
# Acceptance Rate:                        0.433463
# Replacements:                               1000
# Total Samples:                              2307
# Nested Sampling ln(Z):               5913.363530
# Acceptance Rate:                        0.425963
# Replacements:                               1050
# Total Samples:                              2465
# Nested Sampling ln(Z):               6349.363169
#
# UPDATE: Current MaxLogLike =  8038.942699534688
#
# No mnest_results supplied for traces
# Acceptance Rate:                        0.413223
# Replacements:                               1100
# Total Samples:                              2662
# Nested Sampling ln(Z):               6580.860038
# Acceptance Rate:                        0.401396
# Replacements:                               1150
# Total Samples:                              2865
# Nested Sampling ln(Z):               6837.597396
# Acceptance Rate:                        0.392157
# Replacements:                               1200
# Total Samples:                              3060
# Nested Sampling ln(Z):               7037.844472
# Acceptance Rate:                        0.382380
# Replacements:                               1250
# Total Samples:                              3269
# Nested Sampling ln(Z):               7181.927622
# Acceptance Rate:                        0.375397
# Replacements:                               1300
# Total Samples:                              3463
# Nested Sampling ln(Z):               7393.891554
# Acceptance Rate:                        0.368450
# Replacements:                               1350
# Total Samples:                              3664
# Nested Sampling ln(Z):               7565.109847
# Acceptance Rate:                        0.356415
# Replacements:                               1400
# Total Samples:                              3928
# Nested Sampling ln(Z):               7705.806320
# Acceptance Rate:                        0.347389
# Replacements:                               1450
# Total Samples:                              4174
# Nested Sampling ln(Z):               7818.551547
# Acceptance Rate:                        0.335345
# Replacements:                               1500
# Total Samples:                              4473
# Nested Sampling ln(Z):               7908.827362
# Acceptance Rate:                        0.327765
# Replacements:                               1550
# Total Samples:                              4729
# Nested Sampling ln(Z):               7978.840363
# Acceptance Rate:                        0.322841
# Replacements:                               1600
# Total Samples:                              4956
# Nested Sampling ln(Z):               8038.049172
# Acceptance Rate:                        0.316881
# Replacements:                               1650
# Total Samples:                              5207
# Nested Sampling ln(Z):               8096.965028
# Acceptance Rate:                        0.310389
# Replacements:                               1700
# Total Samples:                              5477
# Nested Sampling ln(Z):               8141.663184
# Acceptance Rate:                        0.305837
# Replacements:                               1750
# Total Samples:                              5722
# Nested Sampling ln(Z):               8189.775945
# Acceptance Rate:                        0.303388
# Replacements:                               1800
# Total Samples:                              5933
# Nested Sampling ln(Z):               8221.306054
# Acceptance Rate:                        0.296903
# Replacements:                               1850
# Total Samples:                              6231
# Nested Sampling ln(Z):               8266.728300
# Acceptance Rate:                        0.288491
# Replacements:                               1900
# Total Samples:                              6586
# Nested Sampling ln(Z):               8292.171230
# Acceptance Rate:                        0.283060
# Replacements:                               1950
# Total Samples:                              6889
# Nested Sampling ln(Z):               8316.826628
# Acceptance Rate:                        0.276396
# Replacements:                               2000
# Total Samples:                              7236
# Nested Sampling ln(Z):               8338.447313
# Acceptance Rate:                        0.269170
# Replacements:                               2050
# Total Samples:                              7616
# Nested Sampling ln(Z):               8357.860373
#
# UPDATE: Current MaxLogLike =  8495.804886805134
#
# No mnest_results supplied for traces
# Acceptance Rate:                        0.263257
# Replacements:                               2100
# Total Samples:                              7977
# Nested Sampling ln(Z):               8379.021013
# Acceptance Rate:                        0.257054
# Replacements:                               2150
# Total Samples:                              8364
# Nested Sampling ln(Z):               8395.324731
# Acceptance Rate:                        0.253077
# Replacements:                               2200
# Total Samples:                              8693
# Nested Sampling ln(Z):               8408.389178
# Acceptance Rate:                        0.248482
# Replacements:                               2250
# Total Samples:                              9055
# Nested Sampling ln(Z):               8420.917743
# Acceptance Rate:                        0.241318
# Replacements:                               2300
# Total Samples:                              9531
# Nested Sampling ln(Z):               8432.413759
# Acceptance Rate:                        0.234578
# Replacements:                               2350
# Total Samples:                             10018
# Nested Sampling ln(Z):               8443.993996
# Acceptance Rate:                        0.226715
# Replacements:                               2400
# Total Samples:                             10586
# Nested Sampling ln(Z):               8452.435094
# Acceptance Rate:                        0.220086
# Replacements:                               2450
# Total Samples:                             11132
# Nested Sampling ln(Z):               8459.671939
# Acceptance Rate:                        0.213730
# Replacements:                               2500
# Total Samples:                             11697
# Nested Sampling ln(Z):               8465.691844
# Acceptance Rate:                        0.207317
# Replacements:                               2550
# Total Samples:                             12300
# Nested Sampling ln(Z):               8470.561671
# Acceptance Rate:                        0.204178
# Replacements:                               2600
# Total Samples:                             12734
# Nested Sampling ln(Z):               8475.319764
# Acceptance Rate:                        0.197525
# Replacements:                               2650
# Total Samples:                             13416
# Nested Sampling ln(Z):               8479.768245
# Acceptance Rate:                        0.191259
# Replacements:                               2700
# Total Samples:                             14117
# Nested Sampling ln(Z):               8484.244519
# Acceptance Rate:                        0.185798
# Replacements:                               2750
# Total Samples:                             14801
# Nested Sampling ln(Z):               8487.086860
# Acceptance Rate:                        0.178765
# Replacements:                               2800
# Total Samples:                             15663
# Nested Sampling ln(Z):               8489.541615
# Acceptance Rate:                        0.173221
# Replacements:                               2850
# Total Samples:                             16453
# Nested Sampling ln(Z):               8491.726005
# Acceptance Rate:                        0.168135
# Replacements:                               2900
# Total Samples:                             17248
# Nested Sampling ln(Z):               8493.371681
# Acceptance Rate:                        0.163752
# Replacements:                               2950
# Total Samples:                             18015
# Nested Sampling ln(Z):               8495.015761
# Acceptance Rate:                        0.157290
# Replacements:                               3000
# Total Samples:                             19073
# Nested Sampling ln(Z):               8496.624831
# Acceptance Rate:                        0.152256
# Replacements:                               3050
# Total Samples:                             20032
# Nested Sampling ln(Z):               8498.149533
#
# UPDATE: Current MaxLogLike =  8539.901343138969
#
# No mnest_results supplied for traces
# Acceptance Rate:                        0.146371
# Replacements:                               3100
# Total Samples:                             21179
# Nested Sampling ln(Z):               8499.461035
# Acceptance Rate:                        0.142341
# Replacements:                               3150
# Total Samples:                             22130
# Nested Sampling ln(Z):               8500.560188
# Acceptance Rate:                        0.138919
# Replacements:                               3200
# Total Samples:                             23035
# Nested Sampling ln(Z):               8501.537635
# Acceptance Rate:                        0.134760
# Replacements:                               3250
# Total Samples:                             24117
# Nested Sampling ln(Z):               8502.385347
# Acceptance Rate:                        0.128861
# Replacements:                               3300
# Total Samples:                             25609
# Nested Sampling ln(Z):               8503.026826
# Acceptance Rate:                        0.124698
# Replacements:                               3350
# Total Samples:                             26865
# Nested Sampling ln(Z):               8503.639784
# Acceptance Rate:                        0.119390
# Replacements:                               3400
# Total Samples:                             28478
# Nested Sampling ln(Z):               8504.198828
# Acceptance Rate:                        0.113786
# Replacements:                               3450
# Total Samples:                             30320
# Nested Sampling ln(Z):               8504.730702
# Acceptance Rate:                        0.111579
# Replacements:                               3500
# Total Samples:                             31368
# Nested Sampling ln(Z):               8505.154093
# Acceptance Rate:                        0.106157
# Replacements:                               3550
# Total Samples:                             33441
# Nested Sampling ln(Z):               8505.508876
# Acceptance Rate:                        0.099687
# Replacements:                               3600
# Total Samples:                             36113
# Nested Sampling ln(Z):               8505.820953
# Acceptance Rate:                        0.094798
# Replacements:                               3650
# Total Samples:                             38503
# Nested Sampling ln(Z):               8506.065678
# Acceptance Rate:                        0.089745
# Replacements:                               3700
# Total Samples:                             41228
# Nested Sampling ln(Z):               8506.257555
# Acceptance Rate:                        0.084769
# Replacements:                               3750
# Total Samples:                             44238
# Nested Sampling ln(Z):               8506.400527
# Acceptance Rate:                        0.081578
# Replacements:                               3800
# Total Samples:                             46581
# Nested Sampling ln(Z):               8506.504540
# Acceptance Rate:                        0.079478
# Replacements:                               3850
# Total Samples:                             48441
# Nested Sampling ln(Z):               8506.584715
# Acceptance Rate:                        0.077010
# Replacements:                               3900
# Total Samples:                             50643
# Nested Sampling ln(Z):               8506.646888
#
# UPDATE: Current MaxLogLike =  8544.027252509288
#
# No mnest_results supplied for traces
# Acceptance Rate:                        0.076949
# Replacements:                               3908
# Total Samples:                             50787
# Nested Sampling ln(Z):               8506.654800
#
# UPDATE: Current MaxLogLike =  8544.027252509288
#
# No mnest_results supplied for traces
#  ln(ev)=   8506.8080607651755      +/-  0.58011063961893528
#  Total Likelihood Evaluations:        50787
#  Sampling finished. Exiting MultiNest

# %% [markdown]
# Including astrometry data allows for more parameters to output, but also more plots. Some example of these plots are the `[basename]_astr_remove_pm_1.png`

# %%
display(Image.open('astrom_test_files/photastrom_test_astr_remove_pm_1.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>

# %%
display(Image.open('astrom_test_files/photastrom_test_astr_on_sky_1.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1000x1000>
