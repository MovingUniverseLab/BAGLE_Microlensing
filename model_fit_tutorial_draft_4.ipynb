# %% [markdown]
# # BAGLE: Model Fitting Tutorial
# ### This Jupyter Notebook tutorial introduces how to model fit different microlensing events with the BAGLE model fitting functions. To read full docs, go [here](https://bagle.readthedocs.io/en/latest/PSPL_Solver.html#model_fitter.PSPL_Solver). To learn how to use BAGLE's model function, look at [this tutorial](https://github.com/MovingUniverseLab/BAGLE_Microlensing/blob/main/BAGLE_TUTORIAL.ipynb).
# By default, BAGLE uses a MultiNest sampling algorithm (a nested-sampling alternative to MCMC) with observed data to generate samples from posterior distributions.

# %% [markdown]
# ## Import modules
#
# In the general BAGLE model tutorial, we only needed to import model.py. For the case of model fitting, we will need to import the model.py function along with the model_fitter.py.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <b>Note:</b> For the sake of this tutorial, we will be using fake data based on a real microlensing event. Using this fake data involves importing the fake_data.py file as well. For personal uses, you will not use fake_data.
# </div>

# %%
from bagle import model, model_fitter, fake_data

# %% [markdown]
# Importing the ability to see images and os (to create directories in your base directory to put the output files):

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <b>Note:</b> The below modules will not be necessary when using the fitter. This is only used for the tutorial. Additionally, the make directory are used to signify where the output data and plots will go for this tutorial. Normal usages of the fitter will not necessarily need that code.
# </div>

# %%
from astropy.table import Table
import numpy as np
import os
from PIL import Image
from IPython.display import display
''' 
instead of the usual way of using markdown for images, viewing the images is coded in so that if changes are made
to the code by the user, running the code for the images will reflect these changes.
'''
os.makedirs('fit_files', exist_ok=True)
os.makedirs('astrom_test_files', exist_ok=True)

# %% [markdown]
# ### Import / generate your data

# %% [markdown]
# In any case when modelling a microlensing event, the data you have and the type of event varies. In this tutorial, we will be focusing on an event using only Photometry data and an event with no parallax.

# %%
data, p_in = fake_data.fake_data1()

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <b>Note:</b> fake_data() generates 2 variables: the data used for the fit (data), and the truth values that the data should fit to (p_in). When using this model fitter for real microlensing events, you will not have p_in, and so it is not used in this tutorial.
# </div>

# %% [markdown]
# PSPL_Solver is highly sensitive to which data you import. At minimum, you need Photometry data in the form of arrays in a dictionary. The fake data generator produces a data dictionary with the following key:value pairs:
#
# | Key | Input or Input type | Description |
# | --- | --- | --- |
# | target | NoPar / Par (string) | Describes if the target has or does not have parallax. |
# | phot_data | sim (string) | Source directory for the data. 'sim' is used in the case of simulated data. |
# | phot_files | string | File name of data. |
# | t_phot1 | MJD (array) | Array of times for the first photometric data set |
# | mag1 | magnitudes (array) | Array of magnitudes for the first photometric data set. |
# | mag_err1 | array | Error on previous mag1 array. |
#
# In the case you are fitting an event with astrometry, your dictionary must also include:
# | Key | Input or Input type | Description |
# | --- | --- | --- |
# | ast_data | sim (string) | Source directory for the data. 'sim' is used in the case of simulated data. |
# | ast_files | string | File name of data. |
# | t_ast1 | MJD (array) | Array of times for the first astrometric data set |
# | xpos1 | arcsec (array) | arcsec along East-West increasing to the East |
# | ypos1 | arcsec (array) | arcsec along the North-South increasing to the North |
# | xpos_err1 | array | Error on xpos |
# | ypos_err1 | array | Error on ypos |

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <b>Note:</b> The primary chunk of this tutorial will be using only Photometry data, but your data can still include the astrometry dictionaries, they will just not be used when making the fit.
# </div>

# %% [markdown]
# # Using PSPL_Solver

# %% [markdown]
# First, decide the microlensing model class of the event. This is described as one of the PSPL, BSPL, or PSBL subclasses in BAGLE. An example is:
#
# ```Python
# model.PSPL_Phot_noPar_Param1
# ```
# This takes into account photometry data with no parallax for a PSPL event. More model classes in [documentation](https://bagle.readthedocs.io/en/latest/ModelClass.html).

# %% [markdown]
# Next, you need to declare your fitter with this model in mind and with the data you imported earlier in the following format:
# ```Python
# fitter = model_fitter.PSPL_Solver(data,
#                      model.type)
# ```

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <b>Note:</b> Regardless of what model case you use (PSPL, PSBL, BSPL, etc.), you will still use the PSPL_Solver command. 'PSPL' is used in a general sense when declaring the fitter, and you only need to denote the model type in the model.param argument within the PSPL.solver command.
# </div>

# %% [markdown]
# ### Required arguments:
#
# - data
#   - Dictionary of arrays with required keys
# - model class
#   - Which microlensing model you are trying fit.
#
# ### Optional arguments added in this tutorial:
# - n_live_points (default=300)
#   - Number of points sampled in the priors
# - outputfiles_basename (default= 'chains/1-')
#   - Name of files' output. This name can include a different directory the files are going in.
#
# More arguments in [documentation](https://bagle.readthedocs.io/en/latest/PSPL_Solver.html#model_fitter.PSPL_Solver).

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Tip: </b> Regardless of what model class you use, for the PSPL_solver to work properly you must set n_live_points > dimensionality. When lacking highly fine tuned priors, the suggested number used for n_live_points is 50x your dimensionality. However, usually doing 20x to 30x your dimensionality is common practice. For this tutorial, we will only be using 200 using a model class with dimensionality 7.
# </div>

# %%
fitter = model_fitter.PSPL_Solver(data,
                     model.PSPL_Phot_noPar_Param1,
                     n_live_points=200,
                     outputfiles_basename='fit_files/test_')
# Out:
# ***** WARNING: ASTROMETRY DATA WILL NOT BE FIT BY <class 'bagle.model.PSPL_Phot_noPar_Param1'> *****

# %% [markdown]
# Now that we have our object, we will have to set our priors:

# %% [markdown]
# ## Priors:
#
# In the context of nested sampling, setting priors narrows down the location of where your points within the fit will sample from. Having priors allows for a more accurate plot as it sharpens the efficiency of the points that are sampling. However, making them too small might cause the best parameter to be out of range if you are unsure of the ranges that your value could be in. Set your priors based on information that works best with the data you have about the event.
#
# A prior can be set for any output parameter the model would have. You can find a list of parameters by model in the doumentation for [PSPL](https://bagle.readthedocs.io/en/latest/PSPL.html), [PSBL](https://bagle.readthedocs.io/en/latest/PSBL_Param.html), and [BSPL](https://bagle.readthedocs.io/en/latest/BSPL.html).
#
# Priors should be set in the following way:
# ```Python
# fitter.priors['param'] = model_fitter.make_gen(beginning_prior, ending_prior)
# ```

# %%
fitter.priors['t0'] = model_fitter.make_gen(56990, 57010) #MJD
fitter.priors['b_sff1'] = model_fitter.make_gen(0.5, 1.1) #ratio; no units
fitter.priors['mag_src1'] = model_fitter.make_gen(18.9, 19.1) #magnitude

# %% [markdown]
# To get the residuals plot (and other relevant plots if you include parallax and/ or astrometry), you will need to run your fit. You run your fit with the command `solve()`

# %%
fitter.solve()
# Out:
# *************************************************
# *** Using Prior for prior function. ***
# *************************************************
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  200
#  dimensionality =    7
#  *****************************************************
#  Starting MultiNest
#  generating live points
#  live points generated, starting sampling
# Acceptance Rate:                        0.965251
# Replacements:                                250
# Total Samples:                               259
# Nested Sampling ln(Z):            -242424.698457
# Acceptance Rate:                        0.911854
# Replacements:                                300
# Total Samples:                               329
# Nested Sampling ln(Z):            -181235.268077
# Acceptance Rate:                        0.823529
# Replacements:                                350
# Total Samples:                               425
# Nested Sampling ln(Z):            -157256.783936
# Acceptance Rate:                        0.778210
# Replacements:                                400
# Total Samples:                               514
# Nested Sampling ln(Z):            -132156.251943
# Acceptance Rate:                        0.755034
# Replacements:                                450
# Total Samples:                               596
# Nested Sampling ln(Z):            -111028.229247
# Acceptance Rate:                        0.746269
# Replacements:                                500
# Total Samples:                               670
# Nested Sampling ln(Z):             -84567.187354
# Acceptance Rate:                        0.724638
# Replacements:                                550
# Total Samples:                               759
# Nested Sampling ln(Z):             -63255.216796
# Acceptance Rate:                        0.707547
# Replacements:                                600
# Total Samples:                               848
# Nested Sampling ln(Z):             -48767.172658
# Acceptance Rate:                        0.693703
# Replacements:                                650
# Total Samples:                               937
# Nested Sampling ln(Z):             -36858.550439
# Acceptance Rate:                        0.661626
# Replacements:                                700
# Total Samples:                              1058
# Nested Sampling ln(Z):             -28966.104271
# Acceptance Rate:                        0.648789
# Replacements:                                750
# Total Samples:                              1156
# Nested Sampling ln(Z):             -23550.235986
# Acceptance Rate:                        0.638978
# Replacements:                                800
# Total Samples:                              1252
# Nested Sampling ln(Z):             -18600.491806
# Acceptance Rate:                        0.630564
# Replacements:                                850
# Total Samples:                              1348
# Nested Sampling ln(Z):             -14259.853090
# Acceptance Rate:                        0.624566
# Replacements:                                900
# Total Samples:                              1441
# Nested Sampling ln(Z):             -10899.989758
# Acceptance Rate:                        0.616083
# Replacements:                                950
# Total Samples:                              1542
# Nested Sampling ln(Z):              -8318.999057
# Acceptance Rate:                        0.604961
# Replacements:                               1000
# Total Samples:                              1653
# Nested Sampling ln(Z):              -5980.236825
# Acceptance Rate:                        0.601815
# Replacements:                               1061
# Total Samples:                              1763
# Nested Sampling ln(Z):              -3588.443709
# Acceptance Rate:                        0.589340
# Replacements:                               1161
# Total Samples:                              1970
# Nested Sampling ln(Z):               -604.770833
#
# UPDATE: Current MaxLogLike =  6149.044605758058
#
# Acceptance Rate:                        0.581642
# Replacements:                               1261
# Total Samples:                              2168
# Nested Sampling ln(Z):               1551.531109
# Acceptance Rate:                        0.570650
# Replacements:                               1361
# Total Samples:                              2385
# Nested Sampling ln(Z):               3101.377247
# Acceptance Rate:                        0.564311
# Replacements:                               1461
# Total Samples:                              2589
# Nested Sampling ln(Z):               4187.535123
# Acceptance Rate:                        0.562928
# Replacements:                               1561
# Total Samples:                              2773
# Nested Sampling ln(Z):               4703.960140
# Acceptance Rate:                        0.554406
# Replacements:                               1661
# Total Samples:                              2996
# Nested Sampling ln(Z):               5149.623669
# Acceptance Rate:                        0.548427
# Replacements:                               1761
# Total Samples:                              3211
# Nested Sampling ln(Z):               5451.487450
# Acceptance Rate:                        0.536775
# Replacements:                               1861
# Total Samples:                              3467
# Nested Sampling ln(Z):               5705.441236
# Acceptance Rate:                        0.527151
# Replacements:                               1961
# Total Samples:                              3720
# Nested Sampling ln(Z):               5858.987440
# Acceptance Rate:                        0.519013
# Replacements:                               2061
# Total Samples:                              3971
# Nested Sampling ln(Z):               5962.092631
# Acceptance Rate:                        0.510875
# Replacements:                               2161
# Total Samples:                              4230
# Nested Sampling ln(Z):               6056.094423
#
# UPDATE: Current MaxLogLike =  6292.9447695135
#
# Acceptance Rate:                        0.501664
# Replacements:                               2261
# Total Samples:                              4507
# Nested Sampling ln(Z):               6114.514572
# Acceptance Rate:                        0.496739
# Replacements:                               2361
# Total Samples:                              4753
# Nested Sampling ln(Z):               6153.668803
# Acceptance Rate:                        0.488487
# Replacements:                               2461
# Total Samples:                              5038
# Nested Sampling ln(Z):               6184.279478
# Acceptance Rate:                        0.483025
# Replacements:                               2561
# Total Samples:                              5302
# Nested Sampling ln(Z):               6208.555223
# Acceptance Rate:                        0.481803
# Replacements:                               2661
# Total Samples:                              5523
# Nested Sampling ln(Z):               6226.926949
# Acceptance Rate:                        0.478758
# Replacements:                               2761
# Total Samples:                              5767
# Nested Sampling ln(Z):               6242.692407
# Acceptance Rate:                        0.471567
# Replacements:                               2861
# Total Samples:                              6067
# Nested Sampling ln(Z):               6253.841922
# Acceptance Rate:                        0.465786
# Replacements:                               2961
# Total Samples:                              6357
# Nested Sampling ln(Z):               6261.895542
# Acceptance Rate:                        0.460439
# Replacements:                               3061
# Total Samples:                              6648
# Nested Sampling ln(Z):               6268.051681
# Acceptance Rate:                        0.454624
# Replacements:                               3161
# Total Samples:                              6953
# Nested Sampling ln(Z):               6272.060424
#
# UPDATE: Current MaxLogLike =  6304.066100290268
#
# Acceptance Rate:                        0.449421
# Replacements:                               3261
# Total Samples:                              7256
# Nested Sampling ln(Z):               6275.973161
# Acceptance Rate:                        0.442586
# Replacements:                               3361
# Total Samples:                              7594
# Nested Sampling ln(Z):               6278.575218
# Acceptance Rate:                        0.435346
# Replacements:                               3461
# Total Samples:                              7950
# Nested Sampling ln(Z):               6280.394734
# Acceptance Rate:                        0.429554
# Replacements:                               3561
# Total Samples:                              8290
# Nested Sampling ln(Z):               6281.532412
# Acceptance Rate:                        0.420901
# Replacements:                               3661
# Total Samples:                              8698
# Nested Sampling ln(Z):               6282.309323
# Acceptance Rate:                        0.414253
# Replacements:                               3761
# Total Samples:                              9079
# Nested Sampling ln(Z):               6282.879146
# Acceptance Rate:                        0.407881
# Replacements:                               3861
# Total Samples:                              9466
# Nested Sampling ln(Z):               6283.314652
# Acceptance Rate:                        0.400101
# Replacements:                               3961
# Total Samples:                              9900
# Nested Sampling ln(Z):               6283.651829
# Acceptance Rate:                        0.391951
# Replacements:                               4061
# Total Samples:                             10361
# Nested Sampling ln(Z):               6283.897637
# Acceptance Rate:                        0.387178
# Replacements:                               4161
# Total Samples:                             10747
# Nested Sampling ln(Z):               6284.078205
#
# UPDATE: Current MaxLogLike =  6305.9853472261075
#
# Acceptance Rate:                        0.383574
# Replacements:                               4250
# Total Samples:                             11080
# Nested Sampling ln(Z):               6284.216458
# Acceptance Rate:                        0.380834
# Replacements:                               4300
# Total Samples:                             11291
# Nested Sampling ln(Z):               6284.281057
# Acceptance Rate:                        0.378854
# Replacements:                               4350
# Total Samples:                             11482
# Nested Sampling ln(Z):               6284.345878
# Acceptance Rate:                        0.376519
# Replacements:                               4400
# Total Samples:                             11686
# Nested Sampling ln(Z):               6284.417797
# Acceptance Rate:                        0.373291
# Replacements:                               4450
# Total Samples:                             11921
# Nested Sampling ln(Z):               6284.486838
# Acceptance Rate:                        0.372887
# Replacements:                               4500
# Total Samples:                             12068
# Nested Sampling ln(Z):               6284.545998
# Acceptance Rate:                        0.372188
# Replacements:                               4550
# Total Samples:                             12225
# Nested Sampling ln(Z):               6284.595723
# Acceptance Rate:                        0.371177
# Replacements:                               4600
# Total Samples:                             12393
# Nested Sampling ln(Z):               6284.634968
#
# UPDATE: Current MaxLogLike =  6305.9853472261075
#
# Acceptance Rate:                        0.370719
# Replacements:                               4611
# Total Samples:                             12438
# Nested Sampling ln(Z):               6284.642277
#
# UPDATE: Current MaxLogLike =  6305.9853472261075
#
#  ln(ev)=   6284.8743622775692      +/-  0.30652396834852780
#  Total Likelihood Evaluations:        12438
#  Sampling finished. Exiting MultiNest

# %% [markdown]
# # Analyzing the output

# %% [markdown]
# ### Best fit parameters

# %% [markdown]
# You can get the best fit parameters in the form of a dictionary using `get_best_fit()`

# %%
fitter.get_best_fit()
# Out:
# {'t0': 56999.77314209244,
#  'u0_amp': 0.12469497221439574,
#  'tE': 174.68768349435572,
#  'piE_E': -0.17011887251097613,
#  'piE_N': -0.46659943948268323,
#  'b_sff1': 1.000904372050547,
#  'mag_src1': 18.998877522879457}

# %% [markdown]
# Using the solve function in the model fitter outputs a PNG with the best fit parameters. This allows for a more formalized look at your parameters. These values are the same as we saw above, but in a PNG format. This PNG file is `basename_parameters.png` and look like

# %%
display(Image.open('fit_files/test_parameters.png').crop((0, 0, 1000, 400)))
# Out:
# <PIL.Image.Image image mode=RGBA size=1000x400>

# %% [markdown]
# ## Residuals plot

# %% [markdown]
# A residuals plot shows the observed data points with the best fit model around the data points. A good residuals plot will be one that consistently goes through the observed data points.
#
# You can see this file with `basename_phot_and_residuals_1.png`

# %%
display(Image.open('fit_files/test_phot_and_residuals_1.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1000x1000>

# %% [markdown]
# <b>Top:</b> Shows data points, their errors, and the line of best fit for the observed data.
#
# <b>Bottom:</b> Looks at the generic residuals plot, and subtracts the observed data point by the model it generates. These values are then plotted, with the x-axis staying constant from the generic residuals plot and the y-axis denoting the 'observed minus model'. This plot should be centered around 0, and major deviation with that questions the viability of the model.

# %% [markdown]
# ## Corner and trace plots

# %% [markdown]
# To gain insight into how the parameters would fit and their possible relationship to one another, you will need to run a separate command to output the corner and trace plots. This is done through running `plot_dynesty_style()`. There are several optional arguments for this function, but the most notable is the `fit_vals` argument:
#
# - fit_vals = [string; default=none]
#   - mean
#   - maxl (maximum likelihood)
#     - Found by maximizing the likelihood function (probability density of observed data)
#   - map (maximum a posteriori)
#     - Mode of the posterior distribution. This is a regularization of the maximum likelihood as it incorporates the prior distribution into the output quantity.
#
# Adding this argument adds another line to your plots, which would signify as listed in the form of a red line. They would not affect the content of your corner and trace plots, only adding another line.

# %%
fitter.plot_dynesty_style(fit_vals='maxl')

# %% [markdown]
# The name of the trace and corner files are `basename_dy_trace.png` and `basename_dy_corner.png` respectively.

# %%
display(Image.open('fit_files/test_dy_trace.png'), Image.open('fit_files/test_dy_corner.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1200x2100>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1600x1600>

# %% [markdown]
# <b>Top:</b> Trace plot: The trace plot shows two columns of plots, these plots are:
#
# <i>Left:</i> Evolution of the sample particles as a function of ln(X). The color denotes the weighted importance. In other words, their relative posterior mass.
#
# <i>Right:</i> The marginalized posteriors of the plotted particles graph to the left with a errors of the provided range.
#
# <b>Bottom:</b> Corner plot: On the outside diagonal, these plots are the same 1D posterior distributions seen in the trace plot above. On the inside are the 2D posterior distributions showing the relationship with the two parameters that are aligned for that plot. The more circular or scattered the plot is, the less the two parameters are correlated to one another. The more diagonal and thin the plot is, the more the two parameters are correlated to one another.
#
# In addition to these plots, you can also add a red line (discussed above) which notes each parameters' mean, maximum likelihood, or maximum a posteriori. These are added to the corner and trace plot. You can also get these values from looking into an output summary.fits:

# %%
summary=Table.read('fit_files/test_summary.fits')
summary
# Out:
# <Table length=3>
#      Mean_t0          Mean_u0_amp      ...        logZ            maxlogL
#      float64            float64        ...      float64           float64
# ----------------- -------------------- ... ----------------- ------------------
# 56999.78801008341  0.02442200037652731 ... 6284.642277207109 6305.9853472261075
# 56999.78193204399   0.1255071490788271 ... 6284.358375537008 6305.9853472261075
# 56999.79700995843 -0.12526929427115166 ... 6283.965763617388   6305.90947081778

# %% [markdown]
# # Accuracy

# %% [markdown]
# One thing that is important is a numerical understanding in how accurate this fit is. To get the chi2 value, you can run the function `calc_chi2()`. You will need to divide this value by the degrees of freedom of the fit, which is just the sum of the data points in your array(s) + the number of parameters the fit can output.

# %% [markdown]
# <div class="alert alert-block alert-info">
#     If you are unaware of the number of parameters your fit will output, you can check with <b> len(model_class.fitter_param_names)</b> Additionally, if you are using astrometry data, make sure to add the length of the t_ast1 array to your "data point" summation to have an accurate degree of freedom and chi2 value.
# </div>

# %%
number_of_params=len(model.PSPL_Phot_noPar_Param1.fitter_param_names)
data_points=int(len(data['t_phot1'])) # + int(len(data['t_ast1'])) for PhotAstrom models
dof= data_points-number_of_params

chi2_raw=fitter.calc_chi2(params='best', verbose=False)
chi2=chi2_raw/dof

print('Raw chi2 value : ', chi2_raw, '\nActual chi2 value : ', chi2)
# Out:
# Raw chi2 value :  3906.983865001461
# Actual chi2 value :  0.9587690466261254

# %% [markdown]
# You can also see the raw chi2 values for the best fit parameters through the function `print_likelihood`

# %%
fitter.print_likelihood()
# Out:
# t0            = 56999.773142
# u0_amp        = 0.124695
# tE            = 174.687683
# piE_E         = -0.170119
# piE_N         = -0.466599
# b_sff1        = 1.000904
# mag_src1      = 18.998878
# lnL_phot      = 6305.985347
# lnL_ast       = 0.000000
# lnL           = 6305.985347
# chi2_phot1    = 3906.983865
# chi2_phot     = 3906.983865
# chi2_ast      = -0.000000
# chi2          = 3906.983865
# logL :           6306.0
# chi2 :           3907.0

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <b>Note:</b> The StDev values you can find in the <b>summary.fits</b> file are another way to analyze the accuracy of the fit by parameter as these values describe the errors on the posterior.
# </div>

# %% [markdown]
# # Final notes

# %% [markdown]
# To conclude this tutorial, it is important to note the different information and parameters the model fitter will output given just photometry data or photometry and astrometry data (at least in the case with no parallax).

# %% [markdown]
# ## *Photometry and Photometry-Astrometry output parameters comparisson*
#
# | Parameter | Phot | PhotAstrom | Description | Units |
# | --- | --- | --- | --- | --- |
# | mL |  | X | Lens mass| m_sun
# |t0| X | X | Time of photometric peak| MJD|
# |beta|  | X | Angular distance between lens and source| mas|
# |dL|  | X | Observer distance to lens|pc|
# |dL_dS|  | X | Ratio of observer distance from lens vs source | n/a|
# |XSO_E|  | X | Source at t0 in East direction|arcsec|
# |XSO_N|  | X |Dec of source at t0 |arcsec|
# |muL_E|  | X |RA lens proper motion |mas/yr|
# |mUL_N |  | X |Dec lens proper motion |mas/yr|
# |muS_E|  | X |RA source proper motion |mas/yr|
# |muS_N |  | X |Dec source proper motion |mas/yr|
# |b_sff1 | X | X | Ratio of source flux vs total |n/a|
# |mag_src1| X | X | Source photometric magnitude|n/a|
# |dS |  | X | Obsevrer disnace to source |pc|
# |tE | X | X | Einstein crossing time|days|
# |u0_amp| X | X |Distance apart between lens and source at t0|thetaE|
# |thetaE_E|  | X |Einstein radius in relative proper motion in East direction|mas|
# |thetaE_N|  | X |Einstein radius in relative proper motion in North direction|mas|
# |piE_E| X | X |Microlensing parallax in East direction|thetaE|
# |piE_N| X | X |Microlensing parallax in North Direction|thetaE|
# |muRel_E|  | X |RA source-lens relative proper motion |mas/yr|
# |muRel_N|  | X |Dec source-lens relative proper motion |mas/yr|

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Take away:</b> When you only using photometry, you will have less output parameters than if you include astrometry data. Dimensionality = number of parameters output.
# </div>

# %% [markdown]
# ### Here is an example of using Astrometry with the same fake input data

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     <b>Warning:</b> Processing this fit with astrometry data takes around 2 minutes, so do not close out of the kernel while it runs or the fit will fail.
# </div>

# %%
fitter_ast = model_fitter.PSPL_Solver(data,
                     model.PSPL_PhotAstrom_noPar_Param1,
                     n_live_points=200,
                     outputfiles_basename='astrom_test_files/photastrom_test_')

fitter_ast.priors['mL'] = model_fitter.make_gen(5.0, 15.0) #m_sun
fitter_ast.priors['t0'] = model_fitter.make_gen(56990, 57010) #MJD
fitter_ast.priors['beta'] = model_fitter.make_gen(-0.5, -0.3) #mas
fitter_ast.priors['muL_E'] = model_fitter.make_gen(-1, 1) #mas/yr
fitter_ast.priors['muL_N'] = model_fitter.make_gen(-8, -6) #mas/yr
fitter_ast.priors['muS_E'] = model_fitter.make_gen(0, 3) #mas/yr
fitter_ast.priors['muS_N'] = model_fitter.make_gen(-2, 1) #mas/yr
fitter_ast.priors['dL'] = model_fitter.make_gen(3000, 5000) #pc
fitter_ast.priors['dL_dS'] = model_fitter.make_gen(0.45, 0.55) #ratio; no units
fitter_ast.priors['b_sff1'] = model_fitter.make_gen(0.5, 1.1) #ratio; no units
fitter_ast.priors['mag_src1'] = model_fitter.make_gen(18.9, 19.1) #magnitude
fitter_ast.priors['xS0_E'] = model_fitter.make_gen(-10 ** -3, 10 ** -3) #arcsec
fitter_ast.priors['xS0_N'] = model_fitter.make_gen(-10 ** -3, 10 ** -3) #arcsec

fitter_ast.solve()
fitter_ast.plot_dynesty_style(fit_vals='maxl')
# Out:
# *************************************************
# *** Using Prior for prior function. ***
# *************************************************
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  200
#  dimensionality =   13
#  *****************************************************
#  Starting MultiNest
#  generating live points
#  live points generated, starting sampling
# Acceptance Rate:                        0.976562
# Replacements:                                250
# Total Samples:                               256
# Nested Sampling ln(Z):            -338441.213010
# Acceptance Rate:                        0.911854
# Replacements:                                300
# Total Samples:                               329
# Nested Sampling ln(Z):            -223424.452958
# Acceptance Rate:                        0.857843
# Replacements:                                350
# Total Samples:                               408
# Nested Sampling ln(Z):            -178508.730431
# Acceptance Rate:                        0.836820
# Replacements:                                400
# Total Samples:                               478
# Nested Sampling ln(Z):            -149830.619584
# Acceptance Rate:                        0.810811
# Replacements:                                450
# Total Samples:                               555
# Nested Sampling ln(Z):            -116599.928475
# Acceptance Rate:                        0.793651
# Replacements:                                500
# Total Samples:                               630
# Nested Sampling ln(Z):             -93207.446468
# Acceptance Rate:                        0.767085
# Replacements:                                550
# Total Samples:                               717
# Nested Sampling ln(Z):             -70757.290316
# Acceptance Rate:                        0.750000
# Replacements:                                600
# Total Samples:                               800
# Nested Sampling ln(Z):             -54809.207146
# Acceptance Rate:                        0.738636
# Replacements:                                650
# Total Samples:                               880
# Nested Sampling ln(Z):             -42825.803615
# Acceptance Rate:                        0.722394
# Replacements:                                700
# Total Samples:                               969
# Nested Sampling ln(Z):             -31190.602410
# Acceptance Rate:                        0.698324
# Replacements:                                750
# Total Samples:                              1074
# Nested Sampling ln(Z):             -24518.748460
# Acceptance Rate:                        0.677966
# Replacements:                                800
# Total Samples:                              1180
# Nested Sampling ln(Z):             -20087.380531
# Acceptance Rate:                        0.666144
# Replacements:                                850
# Total Samples:                              1276
# Nested Sampling ln(Z):             -16017.548658
# Acceptance Rate:                        0.646088
# Replacements:                                900
# Total Samples:                              1393
# Nested Sampling ln(Z):             -12673.690996
# Acceptance Rate:                        0.618087
# Replacements:                                950
# Total Samples:                              1537
# Nested Sampling ln(Z):              -9269.716956
# Acceptance Rate:                        0.614251
# Replacements:                               1000
# Total Samples:                              1628
# Nested Sampling ln(Z):              -7224.309423
# Acceptance Rate:                        0.580431
# Replacements:                               1050
# Total Samples:                              1809
# Nested Sampling ln(Z):              -5014.897675
# Acceptance Rate:                        0.562085
# Replacements:                               1100
# Total Samples:                              1957
# Nested Sampling ln(Z):              -3371.462042
# Acceptance Rate:                        0.555019
# Replacements:                               1150
# Total Samples:                              2072
# Nested Sampling ln(Z):              -2094.791194
#
# UPDATE: Current MaxLogLike =  6352.800718066841
#
# No mnest_results supplied for traces
# Acceptance Rate:                        0.543478
# Replacements:                               1200
# Total Samples:                              2208
# Nested Sampling ln(Z):               -990.703245
# Acceptance Rate:                        0.532595
# Replacements:                               1250
# Total Samples:                              2347
# Nested Sampling ln(Z):                -42.551368
# Acceptance Rate:                        0.522718
# Replacements:                               1300
# Total Samples:                              2487
# Nested Sampling ln(Z):                914.822190
# Acceptance Rate:                        0.511751
# Replacements:                               1350
# Total Samples:                              2638
# Nested Sampling ln(Z):               1621.109517
# Acceptance Rate:                        0.506146
# Replacements:                               1400
# Total Samples:                              2766
# Nested Sampling ln(Z):               2266.622749
# Acceptance Rate:                        0.499655
# Replacements:                               1450
# Total Samples:                              2902
# Nested Sampling ln(Z):               2873.661625
# Acceptance Rate:                        0.485909
# Replacements:                               1500
# Total Samples:                              3087
# Nested Sampling ln(Z):               3405.681905
# Acceptance Rate:                        0.474006
# Replacements:                               1550
# Total Samples:                              3270
# Nested Sampling ln(Z):               3916.547110
# Acceptance Rate:                        0.463499
# Replacements:                               1600
# Total Samples:                              3452
# Nested Sampling ln(Z):               4276.067843
# Acceptance Rate:                        0.454921
# Replacements:                               1650
# Total Samples:                              3627
# Nested Sampling ln(Z):               4548.270046
# Acceptance Rate:                        0.449498
# Replacements:                               1700
# Total Samples:                              3782
# Nested Sampling ln(Z):               4768.990102
# Acceptance Rate:                        0.435540
# Replacements:                               1750
# Total Samples:                              4018
# Nested Sampling ln(Z):               5066.122868
# Acceptance Rate:                        0.431241
# Replacements:                               1800
# Total Samples:                              4174
# Nested Sampling ln(Z):               5298.660179
# Acceptance Rate:                        0.426759
# Replacements:                               1850
# Total Samples:                              4335
# Nested Sampling ln(Z):               5509.006368
# Acceptance Rate:                        0.422880
# Replacements:                               1900
# Total Samples:                              4493
# Nested Sampling ln(Z):               5733.044662
# Acceptance Rate:                        0.415956
# Replacements:                               1950
# Total Samples:                              4688
# Nested Sampling ln(Z):               5912.657907
# Acceptance Rate:                        0.410172
# Replacements:                               2000
# Total Samples:                              4876
# Nested Sampling ln(Z):               6124.085244
# Acceptance Rate:                        0.406423
# Replacements:                               2050
# Total Samples:                              5044
# Nested Sampling ln(Z):               6278.315192
# Acceptance Rate:                        0.400000
# Replacements:                               2100
# Total Samples:                              5250
# Nested Sampling ln(Z):               6465.464215
# Acceptance Rate:                        0.394134
# Replacements:                               2150
# Total Samples:                              5455
# Nested Sampling ln(Z):               6580.795315
#
# UPDATE: Current MaxLogLike =  8294.632359982546
#
# No mnest_results supplied for traces
# Acceptance Rate:                        0.392997
# Replacements:                               2200
# Total Samples:                              5598
# Nested Sampling ln(Z):               6697.372696
# Acceptance Rate:                        0.388668
# Replacements:                               2250
# Total Samples:                              5789
# Nested Sampling ln(Z):               6816.315864
# Acceptance Rate:                        0.379726
# Replacements:                               2300
# Total Samples:                              6057
# Nested Sampling ln(Z):               6935.997368
# Acceptance Rate:                        0.376784
# Replacements:                               2350
# Total Samples:                              6237
# Nested Sampling ln(Z):               7041.972953
# Acceptance Rate:                        0.372671
# Replacements:                               2400
# Total Samples:                              6440
# Nested Sampling ln(Z):               7139.453188
# Acceptance Rate:                        0.365127
# Replacements:                               2450
# Total Samples:                              6710
# Nested Sampling ln(Z):               7222.707587
# Acceptance Rate:                        0.359764
# Replacements:                               2500
# Total Samples:                              6949
# Nested Sampling ln(Z):               7321.483911
# Acceptance Rate:                        0.354117
# Replacements:                               2550
# Total Samples:                              7201
# Nested Sampling ln(Z):               7393.075692
# Acceptance Rate:                        0.347130
# Replacements:                               2600
# Total Samples:                              7490
# Nested Sampling ln(Z):               7458.833533
# Acceptance Rate:                        0.339962
# Replacements:                               2650
# Total Samples:                              7795
# Nested Sampling ln(Z):               7509.883700
# Acceptance Rate:                        0.336910
# Replacements:                               2700
# Total Samples:                              8014
# Nested Sampling ln(Z):               7577.842218
# Acceptance Rate:                        0.332567
# Replacements:                               2750
# Total Samples:                              8269
# Nested Sampling ln(Z):               7641.571102
# Acceptance Rate:                        0.330267
# Replacements:                               2800
# Total Samples:                              8478
# Nested Sampling ln(Z):               7695.207901
# Acceptance Rate:                        0.326236
# Replacements:                               2850
# Total Samples:                              8736
# Nested Sampling ln(Z):               7749.598387
# Acceptance Rate:                        0.323950
# Replacements:                               2900
# Total Samples:                              8952
# Nested Sampling ln(Z):               7801.912701
# Acceptance Rate:                        0.320061
# Replacements:                               2950
# Total Samples:                              9217
# Nested Sampling ln(Z):               7848.518597
# Acceptance Rate:                        0.317528
# Replacements:                               3000
# Total Samples:                              9448
# Nested Sampling ln(Z):               7902.818677
# Acceptance Rate:                        0.314563
# Replacements:                               3050
# Total Samples:                              9696
# Nested Sampling ln(Z):               7934.082897
# Acceptance Rate:                        0.312942
# Replacements:                               3100
# Total Samples:                              9906
# Nested Sampling ln(Z):               7971.890276
# Acceptance Rate:                        0.311511
# Replacements:                               3150
# Total Samples:                             10112
# Nested Sampling ln(Z):               7999.162338
#
# UPDATE: Current MaxLogLike =  8468.688536572765
#
# No mnest_results supplied for traces
# Acceptance Rate:                        0.308077
# Replacements:                               3200
# Total Samples:                             10387
# Nested Sampling ln(Z):               8035.431509
# Acceptance Rate:                        0.304964
# Replacements:                               3250
# Total Samples:                             10657
# Nested Sampling ln(Z):               8066.711927
# Acceptance Rate:                        0.303030
# Replacements:                               3300
# Total Samples:                             10890
# Nested Sampling ln(Z):               8104.487804
# Acceptance Rate:                        0.299562
# Replacements:                               3350
# Total Samples:                             11183
# Nested Sampling ln(Z):               8130.578643
# Acceptance Rate:                        0.297645
# Replacements:                               3400
# Total Samples:                             11423
# Nested Sampling ln(Z):               8157.897525
# Acceptance Rate:                        0.295731
# Replacements:                               3450
# Total Samples:                             11666
# Nested Sampling ln(Z):               8177.750489
# Acceptance Rate:                        0.294142
# Replacements:                               3500
# Total Samples:                             11899
# Nested Sampling ln(Z):               8197.886169
# Acceptance Rate:                        0.291198
# Replacements:                               3550
# Total Samples:                             12191
# Nested Sampling ln(Z):               8217.315914
# Acceptance Rate:                        0.287678
# Replacements:                               3600
# Total Samples:                             12514
# Nested Sampling ln(Z):               8235.835944
# Acceptance Rate:                        0.284867
# Replacements:                               3650
# Total Samples:                             12813
# Nested Sampling ln(Z):               8256.846744
# Acceptance Rate:                        0.283026
# Replacements:                               3700
# Total Samples:                             13073
# Nested Sampling ln(Z):               8278.416212
# Acceptance Rate:                        0.280374
# Replacements:                               3750
# Total Samples:                             13375
# Nested Sampling ln(Z):               8294.605141
# Acceptance Rate:                        0.278286
# Replacements:                               3800
# Total Samples:                             13655
# Nested Sampling ln(Z):               8312.226705
# Acceptance Rate:                        0.274882
# Replacements:                               3850
# Total Samples:                             14006
# Nested Sampling ln(Z):               8327.472908
# Acceptance Rate:                        0.272232
# Replacements:                               3900
# Total Samples:                             14326
# Nested Sampling ln(Z):               8339.351833
# Acceptance Rate:                        0.268726
# Replacements:                               3950
# Total Samples:                             14699
# Nested Sampling ln(Z):               8352.716437
# Acceptance Rate:                        0.265728
# Replacements:                               4000
# Total Samples:                             15053
# Nested Sampling ln(Z):               8360.389001
# Acceptance Rate:                        0.264619
# Replacements:                               4050
# Total Samples:                             15305
# Nested Sampling ln(Z):               8372.091292
# Acceptance Rate:                        0.262602
# Replacements:                               4100
# Total Samples:                             15613
# Nested Sampling ln(Z):               8384.044392
# Acceptance Rate:                        0.259911
# Replacements:                               4150
# Total Samples:                             15967
# Nested Sampling ln(Z):               8395.197157
#
# UPDATE: Current MaxLogLike =  8528.934030962117
#
# No mnest_results supplied for traces
# Acceptance Rate:                        0.257811
# Replacements:                               4200
# Total Samples:                             16291
# Nested Sampling ln(Z):               8403.408775
# Acceptance Rate:                        0.256519
# Replacements:                               4250
# Total Samples:                             16568
# Nested Sampling ln(Z):               8411.777865
# Acceptance Rate:                        0.255042
# Replacements:                               4300
# Total Samples:                             16860
# Nested Sampling ln(Z):               8418.591416
# Acceptance Rate:                        0.253497
# Replacements:                               4350
# Total Samples:                             17160
# Nested Sampling ln(Z):               8425.420943
# Acceptance Rate:                        0.251013
# Replacements:                               4400
# Total Samples:                             17529
# Nested Sampling ln(Z):               8430.709896
# Acceptance Rate:                        0.248298
# Replacements:                               4450
# Total Samples:                             17922
# Nested Sampling ln(Z):               8437.184596
# Acceptance Rate:                        0.246171
# Replacements:                               4500
# Total Samples:                             18280
# Nested Sampling ln(Z):               8442.745327
# Acceptance Rate:                        0.243955
# Replacements:                               4550
# Total Samples:                             18651
# Nested Sampling ln(Z):               8449.000376
# Acceptance Rate:                        0.241052
# Replacements:                               4600
# Total Samples:                             19083
# Nested Sampling ln(Z):               8454.389851
# Acceptance Rate:                        0.238303
# Replacements:                               4650
# Total Samples:                             19513
# Nested Sampling ln(Z):               8459.074807
# Acceptance Rate:                        0.235956
# Replacements:                               4700
# Total Samples:                             19919
# Nested Sampling ln(Z):               8464.424153
# Acceptance Rate:                        0.234313
# Replacements:                               4750
# Total Samples:                             20272
# Nested Sampling ln(Z):               8468.541910
# Acceptance Rate:                        0.231158
# Replacements:                               4800
# Total Samples:                             20765
# Nested Sampling ln(Z):               8473.159786
# Acceptance Rate:                        0.227465
# Replacements:                               4850
# Total Samples:                             21322
# Nested Sampling ln(Z):               8477.442952
# Acceptance Rate:                        0.225412
# Replacements:                               4900
# Total Samples:                             21738
# Nested Sampling ln(Z):               8480.709499
# Acceptance Rate:                        0.221824
# Replacements:                               4950
# Total Samples:                             22315
# Nested Sampling ln(Z):               8484.440302
# Acceptance Rate:                        0.218943
# Replacements:                               5000
# Total Samples:                             22837
# Nested Sampling ln(Z):               8487.216056
# Acceptance Rate:                        0.214848
# Replacements:                               5050
# Total Samples:                             23505
# Nested Sampling ln(Z):               8489.515121
# Acceptance Rate:                        0.213309
# Replacements:                               5100
# Total Samples:                             23909
# Nested Sampling ln(Z):               8491.857718
# Acceptance Rate:                        0.209810
# Replacements:                               5150
# Total Samples:                             24546
# Nested Sampling ln(Z):               8495.060349
#
# UPDATE: Current MaxLogLike =  8555.428223049015
#
# No mnest_results supplied for traces
# Acceptance Rate:                        0.206562
# Replacements:                               5200
# Total Samples:                             25174
# Nested Sampling ln(Z):               8496.869248
# Acceptance Rate:                        0.203410
# Replacements:                               5250
# Total Samples:                             25810
# Nested Sampling ln(Z):               8498.704902
# Acceptance Rate:                        0.201705
# Replacements:                               5300
# Total Samples:                             26276
# Nested Sampling ln(Z):               8500.680848
# Acceptance Rate:                        0.198339
# Replacements:                               5350
# Total Samples:                             26974
# Nested Sampling ln(Z):               8502.472148
# Acceptance Rate:                        0.196728
# Replacements:                               5400
# Total Samples:                             27449
# Nested Sampling ln(Z):               8504.462427
# Acceptance Rate:                        0.194185
# Replacements:                               5450
# Total Samples:                             28066
# Nested Sampling ln(Z):               8506.118257
# Acceptance Rate:                        0.192240
# Replacements:                               5500
# Total Samples:                             28610
# Nested Sampling ln(Z):               8507.555311
# Acceptance Rate:                        0.190264
# Replacements:                               5550
# Total Samples:                             29170
# Nested Sampling ln(Z):               8508.879454
# Acceptance Rate:                        0.188406
# Replacements:                               5600
# Total Samples:                             29723
# Nested Sampling ln(Z):               8510.488662
# Acceptance Rate:                        0.186033
# Replacements:                               5650
# Total Samples:                             30371
# Nested Sampling ln(Z):               8511.923670
# Acceptance Rate:                        0.183670
# Replacements:                               5700
# Total Samples:                             31034
# Nested Sampling ln(Z):               8513.148273
# Acceptance Rate:                        0.180381
# Replacements:                               5750
# Total Samples:                             31877
# Nested Sampling ln(Z):               8514.425536
# Acceptance Rate:                        0.177991
# Replacements:                               5800
# Total Samples:                             32586
# Nested Sampling ln(Z):               8515.488438
# Acceptance Rate:                        0.173843
# Replacements:                               5850
# Total Samples:                             33651
# Nested Sampling ln(Z):               8516.488352
# Acceptance Rate:                        0.169789
# Replacements:                               5900
# Total Samples:                             34749
# Nested Sampling ln(Z):               8517.596134
# Acceptance Rate:                        0.167168
# Replacements:                               5950
# Total Samples:                             35593
# Nested Sampling ln(Z):               8518.568757
# Acceptance Rate:                        0.163975
# Replacements:                               6000
# Total Samples:                             36591
# Nested Sampling ln(Z):               8519.362219
# Acceptance Rate:                        0.160678
# Replacements:                               6050
# Total Samples:                             37653
# Nested Sampling ln(Z):               8520.109555
# Acceptance Rate:                        0.158047
# Replacements:                               6100
# Total Samples:                             38596
# Nested Sampling ln(Z):               8520.783290
# Acceptance Rate:                        0.156341
# Replacements:                               6150
# Total Samples:                             39337
# Nested Sampling ln(Z):               8521.408935
#
# UPDATE: Current MaxLogLike =  8562.571221259399
#
# No mnest_results supplied for traces
# Acceptance Rate:                        0.154079
# Replacements:                               6200
# Total Samples:                             40239
# Nested Sampling ln(Z):               8521.991050
# Acceptance Rate:                        0.152499
# Replacements:                               6250
# Total Samples:                             40984
# Nested Sampling ln(Z):               8522.534023
# Acceptance Rate:                        0.150480
# Replacements:                               6300
# Total Samples:                             41866
# Nested Sampling ln(Z):               8523.026592
# Acceptance Rate:                        0.147171
# Replacements:                               6350
# Total Samples:                             43147
# Nested Sampling ln(Z):               8523.471730
# Acceptance Rate:                        0.144973
# Replacements:                               6400
# Total Samples:                             44146
# Nested Sampling ln(Z):               8523.915480
# Acceptance Rate:                        0.143114
# Replacements:                               6450
# Total Samples:                             45069
# Nested Sampling ln(Z):               8524.372442
# Acceptance Rate:                        0.141123
# Replacements:                               6500
# Total Samples:                             46059
# Nested Sampling ln(Z):               8524.799134
# Acceptance Rate:                        0.138892
# Replacements:                               6550
# Total Samples:                             47159
# Nested Sampling ln(Z):               8525.186864
# Acceptance Rate:                        0.135276
# Replacements:                               6600
# Total Samples:                             48789
# Nested Sampling ln(Z):               8525.552740
# Acceptance Rate:                        0.132732
# Replacements:                               6650
# Total Samples:                             50101
# Nested Sampling ln(Z):               8525.870612
# Acceptance Rate:                        0.131360
# Replacements:                               6700
# Total Samples:                             51005
# Nested Sampling ln(Z):               8526.151403
# Acceptance Rate:                        0.129690
# Replacements:                               6750
# Total Samples:                             52047
# Nested Sampling ln(Z):               8526.412897
# Acceptance Rate:                        0.127160
# Replacements:                               6800
# Total Samples:                             53476
# Nested Sampling ln(Z):               8526.679175
# Acceptance Rate:                        0.125527
# Replacements:                               6850
# Total Samples:                             54570
# Nested Sampling ln(Z):               8526.930435
# Acceptance Rate:                        0.123654
# Replacements:                               6900
# Total Samples:                             55801
# Nested Sampling ln(Z):               8527.169811
# Acceptance Rate:                        0.121691
# Replacements:                               6950
# Total Samples:                             57112
# Nested Sampling ln(Z):               8527.393842
# Acceptance Rate:                        0.119658
# Replacements:                               7000
# Total Samples:                             58500
# Nested Sampling ln(Z):               8527.585966
# Acceptance Rate:                        0.118057
# Replacements:                               7050
# Total Samples:                             59717
# Nested Sampling ln(Z):               8527.754137
# Acceptance Rate:                        0.116853
# Replacements:                               7100
# Total Samples:                             60760
# Nested Sampling ln(Z):               8527.902180
# Acceptance Rate:                        0.114484
# Replacements:                               7150
# Total Samples:                             62454
# Nested Sampling ln(Z):               8528.035869
#
# UPDATE: Current MaxLogLike =  8566.876519753987
#
# No mnest_results supplied for traces
# Acceptance Rate:                        0.112458
# Replacements:                               7200
# Total Samples:                             64024
# Nested Sampling ln(Z):               8528.154188
# Acceptance Rate:                        0.111230
# Replacements:                               7250
# Total Samples:                             65180
# Nested Sampling ln(Z):               8528.258316
# Acceptance Rate:                        0.110164
# Replacements:                               7300
# Total Samples:                             66265
# Nested Sampling ln(Z):               8528.349471
# Acceptance Rate:                        0.109258
# Replacements:                               7350
# Total Samples:                             67272
# Nested Sampling ln(Z):               8528.431666
# Acceptance Rate:                        0.108433
# Replacements:                               7400
# Total Samples:                             68245
# Nested Sampling ln(Z):               8528.508863
# Acceptance Rate:                        0.107460
# Replacements:                               7450
# Total Samples:                             69328
# Nested Sampling ln(Z):               8528.578146
# Acceptance Rate:                        0.106667
# Replacements:                               7500
# Total Samples:                             70312
# Nested Sampling ln(Z):               8528.641144
# Acceptance Rate:                        0.105590
# Replacements:                               7550
# Total Samples:                             71503
# Nested Sampling ln(Z):               8528.698064
# Acceptance Rate:                        0.104881
# Replacements:                               7600
# Total Samples:                             72463
# Nested Sampling ln(Z):               8528.749089
# Acceptance Rate:                        0.104090
# Replacements:                               7650
# Total Samples:                             73494
# Nested Sampling ln(Z):               8528.794830
# Acceptance Rate:                        0.103281
# Replacements:                               7700
# Total Samples:                             74554
# Nested Sampling ln(Z):               8528.836366
# Acceptance Rate:                        0.102530
# Replacements:                               7750
# Total Samples:                             75588
# Nested Sampling ln(Z):               8528.874131
# Acceptance Rate:                        0.101382
# Replacements:                               7800
# Total Samples:                             76937
# Nested Sampling ln(Z):               8528.909149
# Acceptance Rate:                        0.100531
# Replacements:                               7850
# Total Samples:                             78085
# Nested Sampling ln(Z):               8528.941083
# Acceptance Rate:                        0.099566
# Replacements:                               7900
# Total Samples:                             79344
# Nested Sampling ln(Z):               8528.969869
# Acceptance Rate:                        0.098392
# Replacements:                               7950
# Total Samples:                             80799
# Nested Sampling ln(Z):               8528.995756
#
# UPDATE: Current MaxLogLike =  8567.223328733802
#
# No mnest_results supplied for traces
# Acceptance Rate:                        0.097540
# Replacements:                               7983
# Total Samples:                             81843
# Nested Sampling ln(Z):               8529.011195
#
# UPDATE: Current MaxLogLike =  8567.223328733802
#
# No mnest_results supplied for traces
#  ln(ev)=   8529.1460058746688      +/-  0.41088103631381456
#  Total Likelihood Evaluations:        81843
#  Sampling finished. Exiting MultiNest

# %% [markdown]
# Including astrometry data allows for more parameters to output, but also more plots. Some example of these plots are the `[basename]_astr_remove_pm_1.png`

# %%
display(Image.open('astrom_test_files/photastrom_test_astr_remove_pm_1.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>

# %% [markdown]
# This plot looks at astrometric shift without proper motion (hence 'remove_pm' in the image title) of the micorlensing event by change in dec (y-axis) and RA (x-axis). In understanding that the model we used is with no parallax, something that looks like a loop is to be expected. The color bar denotes the time of observation for the data in MJD.
#
# Another new type of plot you'll see when adding astrometry data in your fitting run is `[basename]_astr_on_sky_1.png`

# %%
display(Image.open('astrom_test_files/photastrom_test_astr_on_sky_1.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1000x1000>

# %% [markdown]
# This plot is the astrometry plot without subtracting proper motion by dec (y-axis) and RA (x-axis). The wobble in the middle of the plot shows that the event analyzed is a microlensing event between two (or more) objects. A comparison, for example, is that when looking at a single star, this line will be generally straight across without the wobble in the middle. Keep in mind this is without parallax.

# %% [markdown]
# # Running alternatives
# Running fits in a Jupyter notebook is highly advised against as Jupyter runs slowly and eats up RAM quickly. A work around is to put all your fit code into a .py file and run it with the code `python path/example_file.py`. Even with running it through python though, most fits will take hours to even weeks to run depending on the data, priors, or model. A way to make this work faster is to run your .py file faster is through multithreading. The code you will use to multithread is: `mpirun -np -4 python path/example_file.py` where the 4 represents the number of threads you are using. It does not exactly have to be 4, this was just used as an example.
